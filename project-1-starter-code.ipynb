# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 15px; height: 80px">
#
# # Project 1
#
# ### Building "Pokemon Stay"
#
# ---
#
# After reading the gushing praise for Pokemon Go you decide to download it and try it out for yourself. Yet a couple hours of play later you find yourself disappointed by the fact that you _actually_ have to move around outside.
#
# Though just a beginner programmer, you decide to make your own iteration on the genre: "Pokemon Stay". In this version players still need to move, but just from website to website. Pokemon gyms are now popular cyber-destinations, and catching pokemon in the "wild" simply requires browsing the internet for hours in the comfort of your home.
#
# ---
#
# #### Package imports
#
# The `pprint` package below is the only package imported here, and it's not even strictly required to do any of the project. Printing python variables and objects with pprint can help to format them in a "prettier" way.

# %%
from pprint import pprint

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 1. Defining a player
#
# ---
#
# The player variables are:
#
#     player_id : id code unique to each player (integer)
#     player_name : entered name of the player (string)
#     time_played : number of time played the game in minutes (float)
#     player_pokemon: the player's captured pokemon (dictionary)
#     gyms_visited: ids of the gyms that a player has visited (list)
#
# Create a player. The dictionary and list variables should just be defined as empty at this point.

# %%
player_id = 1 
player_name = "Draco"
time_played = 25.0
player_pokemon = {}
gyms_visited = []

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 2. Defining "gym" locations
#
# ---
#
# As the sole programmer, Pokemon Stay will have to start small. To begin, there will be 10 different gym location websites on the internet. The gym locations are:
#
#     1. 'reddit.com'
#     2. 'amazon.com'
#     3. 'twitter.com'
#     4. 'linkedin.com'
#     5. 'ebay.com'
#     6. 'netflix.com'
#     7. 'amazon.com'
#     8. 'stackoverflow.com'
#     9. 'github.com'
#     10. 'quora.com'
#
# 1. Set up a list of all the gym locations. This will be a list of strings.
# 2. Append two of these locations to your player's list of visited gyms.
# 3. Print the list.

# %%
# Example output:
# 
# ['amazon.com', 'ebay.com']

gym_locations = ['reddit.com','amazon.com','twitter.com','linkedin.com','ebay.com','netflix.com','amazon.com','stackoverflow.com','github.com','quora.com']
gyms_visited.append('reddit.com')
gyms_visited.append('twitter.com')
print gyms_visited
# Out:
# ['reddit.com', 'twitter.com']

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 3. Create a pokedex
#
# ---
#
# We also need to create some pokemon to catch. Each pokemon will be defined by these variables:
#
#     pokemon_id : unique identifier for each pokemon (integer)
#     name : the name of the pokemon (string)
#     type : the category of pokemon (string)
#     hp : base hitpoints (integer)
#     attack : base attack (integer)
#     defense : base defense (integer)
#     special_attack : base special attack (integer)
#     special_defense : base sepecial defense (integer)
#     speed : base speed (integer)
#
# We are only going to create 3 different pokemon with these `pokemon_id` and `pokemon_name` values:
#
#     1 : 'charmander'
#     2 : 'squirtle'
#     3 : 'bulbasaur'
#
# Create a dictionary that will contain the pokemon. The keys of the dictionary will be the `pokemon_id` and the values will themselves dictionaries that contain the other pokemon variables. The structure of the pokedex dictionary will start like so:
#
#      {
#          1: {
#                  'name':'charmander',
#                  'type':'fire',
#                  ...
#
# The `type` of charmander, squirtle, and bulbasaur should be `'fire'`, `'water'`, and `'poison'` respectively. The other values are up to you, make them anything you like!
#
# Print the pokedex dictionary with the 3 pokemon.

# %%
# No example output... too similar to the answer!


pokedex = {
    1: { 
            'name':'charmander',
            'type':'fire',
            'hp' : 10,
            'attack' : 7,
            'defense' : 4,
            'special_attack' : 2,
            'special_defense' : 0,
            'speed' : 4
    },
    2: { 
            'name':'squirtle',
            'type':'water',
            'hp' : 10,
            'attack' : 6,
            'defense' : 5,
            'special_attack' : 1,
            'special_defense' : 1,
            'speed' : 4
    },
    3: {
            'name':'bulbasaur',
            'type':'poison',
            'hp' : 12,
            'attack' : 3,
            'defense' : 7,
            'special_attack' : 1,
            'special_defense' : 3,
            'speed' : 3
    }
}

for key,value in pokedex.items():
    print key,value
# Out:
# 1 {'attack': 7, 'defense': 4, 'name': 'charmander', 'special_attack': 2, 'speed': 4, 'hp': 10, 'type': 'fire', 'special_defense': 0}
# 2 {'attack': 6, 'defense': 5, 'name': 'squirtle', 'special_attack': 1, 'speed': 4, 'hp': 10, 'type': 'water', 'special_defense': 1}
# 3 {'attack': 3, 'defense': 7, 'name': 'bulbasaur', 'special_attack': 1, 'speed': 3, 'hp': 12, 'type': 'poison', 'special_defense': 3}

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 4. Create a data structure for players
#
# ---
#
# ### 4.1
#
# In order to maintain a database of multiple players, create a dictionary that keeps track of players indexed by `player_id`.
#
# The keys of the dictionary will be `player_id` and values will be dictionaries containing each player's variables (from question 1). **The values in the player's dictionary will be the variables you assigned in question 1.**
#
# Construct the `players` dictionary and insert the player that you defined in question 1, then print `players`.

# %%
# Example output from print:
#
# {1: {'gyms_visited': ['amazon.com', 'ebay.com'],
#      'player_name': 'Ash',
#      'player_pokemon': {},
#      'time_played': 0.0}}

players = {
            1:{
                'gyms_visited': gyms_visited,
                'player_name': player_name,
                'player_pokemon': player_pokemon, 
                'time_played': time_played
                }
    }

for key,value in players.items():
    print key,value
# Out:
# 1 {'time_played': 25.0, 'gyms_visited': ['reddit.com', 'twitter.com'], 'player_name': 'Draco', 'player_pokemon': {}}

# %% [markdown]
# ---
#
# ### 4.2
#
# Create a new player with `player_id = 2` in the `players` dictionary. Leave the `'player_pokemon'` dictionary empty. Append `'stackoverflow.com'` and `'github.com'` to the `'gyms_visited'` list for player 2.
#
# The `'player_name'` and `'time_played'` values are up to you, but must be a string and float, respectively.
#
# Remember, the player_id is the key for the player in the players dictionary.
#
# Print the `players` dictionary with the new player inserted.

# %%
# No example output. 

players[2] = {'gyms_visited':[],'player_name':'Harry','player_pokemon':{},'time_played':32.0}

players[2]['gyms_visited'].append('github.com')
players[2]['gyms_visited'].append('stackoverflow.com')

for key,value in players.items():
    print key,value
# Out:
# 1 {'time_played': 25.0, 'gyms_visited': ['reddit.com', 'twitter.com'], 'player_name': 'Draco', 'player_pokemon': {}}
# 2 {'time_played': 32.0, 'gyms_visited': ['github.com', 'stackoverflow.com'], 'player_name': 'Harry', 'player_pokemon': {}}

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 5. Add captured pokemon for each player
#
# ---
#
# The `'player_pokemon'` keyed dictionaries for each player keep track of which of the pokemon each player has.
#
# The keys of the `'player_pokemon'` dictionaries are the pokemon ids that correspond to the ids in the `pokedex` dictionary you created earlier. The values are integers specifying the stats for the pokemon.
#
# Give player 1 a squirtle. Give player 2 charmander and a bulbasaur.
#
# Print the players dictionary after adding the pokemon for each player.

# %%
# Example output from print:
#
# {1: {'gyms_visited': ['amazon.com', 'ebay.com'],
#      'player_name': 'Ash',
#      'player_pokemon': {2: ...squirtle dictionary...},
#      'time_played': 0.0},
#  2: {'gyms_visited': ['stackoverflow.com', 'github.com'],
#      'player_name': 'Brock',
#      'player_pokemon': {1: ...charmander dictionary..., 3: ...bulbasaur dictionary...},
#      'time_played': 10.0}}

def poke_update(player_id,pokemon_name):
    for poke_id in pokedex:
        if pokedex[poke_id]['name'] == pokemon_name:
            lookup_id = poke_id
 
    players[player_id]['player_pokemon'].update({lookup_id : pokedex[lookup_id]})

poke_update(1,'squirtle')
poke_update(2,'charmander')
poke_update(2,'bulbasaur')

for key,value in players.items():
    print key,value
# Out:
# 1 {'time_played': 25.0, 'gyms_visited': ['reddit.com', 'twitter.com'], 'player_name': 'Draco', 'player_pokemon': {2: {'attack': 6, 'defense': 5, 'name': 'squirtle', 'special_attack': 1, 'speed': 4, 'hp': 10, 'type': 'water', 'special_defense': 1}}}
# 2 {'time_played': 32.0, 'gyms_visited': ['github.com', 'stackoverflow.com'], 'player_name': 'Harry', 'player_pokemon': {1: {'attack': 7, 'defense': 4, 'name': 'charmander', 'special_attack': 2, 'speed': 4, 'hp': 10, 'type': 'fire', 'special_defense': 0}, 3: {'attack': 3, 'defense': 7, 'name': 'bulbasaur', 'special_attack': 1, 'speed': 3, 'hp': 12, 'type': 'poison', 'special_defense': 3}}}

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 6. What gyms have players visited?
#
# ---
#
# Write a for-loop that:
#
# 1. Iterates through the `pokemon_gyms` list of gym locations you defined before.
# 2. For each gym, iterate through each player in the `players` dictionary with a second, internal for-loop.
# 3. If the player has visited the gym, print out "[player] has visited [gym location].", filling in [player] and [gym location] with the current player's name and current gym location.

# %%
# Example output:
#
# Ash has visited amazon.com.
# Ash has visited ebay.com.
# Ash has visited amazon.com.
# Brock has visited stackoverflow.com.
# Brock has visited github.com.

for gym in gym_locations:
    for player in players:
        if gym in players[player]['gyms_visited']:
            print players[player]['player_name'] + ' has visited ' + gym
# Out:
# Draco has visited reddit.com
# Draco has visited twitter.com
# Harry has visited stackoverflow.com
# Harry has visited github.com

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 7. Calculate player "power".
#
# ---
#
# Define a function that will calculate a player's "power". Player power is defined as the sum of the base statistics all of their pokemon.
#
# Your function will:
#
# 1. Accept the `players` dictionary, `pokedex` dictionary, and a player_id as arguments.
# 2. For the specified player_id, look up that player's pokemon and their level(s).
# 3. Find and aggregate the attack and defense values for each of the player's pokemon from the `pokedex` dictionary.
# 4. Print "[player name]'s power is [player power].", where the player power is the sum of the base statistics for all of their pokemon.
# 5. Return the player's power value.
#
# Print out the pokemon power for each of your players.

# %%
# Example output:
#
# Ash's power is 57.
# 57
# Brock's power is 119.
# 119

def player_power(players,player_id):
    power_total = []
    for pokemon in players[player_id]['player_pokemon'].values():
        power_total.append(pokemon['attack'] + pokemon['defense'])
    print players[player_id]['player_name'] + "'s power is " + str(sum(power_total))
        
player_power(players,1)
player_power(players,2)
# Out:
# Draco's power is 11
# Harry's power is 21

# %% [markdown]
# <img src="http://imgur.com/GCAf1UX.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 8. Load a pokedex file containing all the pokemon
#
# ---
#
# ### 8.1
#
# Now we have access to the raw base stats on all of the pokemon, scraped from the web.
#
# The provided code below loads information from a comma separated value (csv) file. You need to parse this string into a more useable format. The format of the string is:
#
# - Rows are separated by newline characters: \n
# - Columns are separated by commas: ,
# - All cells in the csv are double quoted. Ex: "PokedexNumber" is the first cell of the first row.
#
# Using for-loops, create a list of lists where each list within the overall list is a row of the csv/matrix, and each element in that list is a cell in that row. Additional criteria:
#
# 1. Quotes are removed from each cell item.
# 2. Numeric column values are converted to floats.
# 3. There are some cells that are empty and have no information. For these cells put a -1 value in place.
#
# The first three lists in your pokedex list should look like so:
#
#     ['PokedexNumber', 'Name', 'Type', 'Total', 'HP', 'Attack', 'Defense', 'SpecialAttack', 'SpecialDefense', 'Speed']
#     [1.0, 'Bulbasaur', 'GrassPoison', 318.0, 45.0, 49.0, 49.0, 65.0, 65.0, 45.0]
#     [2.0, 'Ivysaur', 'GrassPoison', 405.0, 60.0, 62.0, 63.0, 80.0, 80.0, 60.0]

# %%
# Code to read in pokedex info
raw_pd = ''
pokedex_file = '/Users/alexanderhalcomb/Desktop/DSI-SF-2-alexhalcomb/datasets/pokemon/pokedex_basic.csv'
with open(pokedex_file, 'r') as f:
    raw_pd = f.read()

raw_pd
    
# the pokedex string is assigned to the raw_pd variable
# Out:
# '"PokedexNumber","Name","Type","Total","HP","Attack","Defense","SpecialAttack","SpecialDefense","Speed"\n"001","Bulbasaur","GrassPoison","318","45","49","49","65","65","45"\n"002","Ivysaur","GrassPoison","405","60","62","63","80","80","60"\n"003","Venusaur","GrassPoison","525","80","82","83","100","100","80"\n"003","VenusaurMega Venusaur","GrassPoison","625","80","100","123","122","120","80"\n"004","Charmander","Fire","309","39","52","43","60","50","65"\n"005","Charmeleon","Fire","405","58","64","58","80","65","80"\n"006","Charizard","FireFlying","534","78","84","78","109","85","100"\n"006","CharizardMega Charizard X","FireDragon","634","78","130","111","130","85","100"\n"006","CharizardMega Charizard Y","FireFlying","634","78","104","78","159","115","100"\n"007","Squirtle","Water","314","44","48","65","50","64","43"\n"008","Wartortle","Water","405","59","63","80","65","80","58"\n"009","Blastoise","Water","530","79","83","100","85","105","78"\n"009","BlastoiseMega Blastoise","Water","630","79","103","120","135","115","78"\n"010","Caterpie","Bug","195","45","30","35","20","20","45"\n"011","Metapod","Bug","205","50","20","55","25","25","30"\n"012","Butterfree","BugFlying","395","60","45","50","90","80","70"\n"013","Weedle","BugPoison","195","40","35","30","20","20","50"\n"014","Kakuna","BugPoison","205","45","25","50","25","25","35"\n"015","Beedrill","BugPoison","395","65","90","40","45","80","75"\n"015","BeedrillMega Beedrill","BugPoison","495","65","150","40","15","80","145"\n"016","Pidgey","NormalFlying","251","40","45","40","35","35","56"\n"017","Pidgeotto","NormalFlying","349","63","60","55","50","50","71"\n"018","Pidgeot","NormalFlying","479","83","80","75","70","70","101"\n"018","PidgeotMega Pidgeot","NormalFlying","579","83","80","80","135","80","121"\n"019","Rattata","Normal","253","30","56","35","25","35","72"\n"020","Raticate","Normal","413","55","81","60","50","70","97"\n"021","Spearow","NormalFlying","262","40","60","30","31","31","70"\n"022","Fearow","NormalFlying","442","65","90","65","61","61","100"\n"023","Ekans","Poison","288","35","60","44","40","54","55"\n"024","Arbok","Poison","438","60","85","69","65","79","80"\n"025","Pikachu","Electric","320","35","55","40","50","50","90"\n"026","Raichu","Electric","485","60","90","55","90","80","110"\n"027","Sandshrew","Ground","300","50","75","85","20","30","40"\n"028","Sandslash","Ground","450","75","100","110","45","55","65"\n"029","Nidoran\xe2\x99\x80","Poison","275","55","47","52","40","40","41"\n"030","Nidorina","Poison","365","70","62","67","55","55","56"\n"031","Nidoqueen","PoisonGround","505","90","92","87","75","85","76"\n"032","Nidoran\xe2\x99\x82","Poison","273","46","57","40","40","40","50"\n"033","Nidorino","Poison","365","61","72","57","55","55","65"\n"034","Nidoking","PoisonGround","505","81","102","77","85","75","85"\n"035","Clefairy","Fairy","323","70","45","48","60","65","35"\n"036","Clefable","Fairy","483","95","70","73","95","90","60"\n"037","Vulpix","Fire","299","38","41","40","50","65","65"\n"038","Ninetales","Fire","505","73","76","75","81","100","100"\n"039","Jigglypuff","NormalFairy","270","115","45","20","45","25","20"\n"040","Wigglytuff","NormalFairy","435","140","70","45","85","50","45"\n"041","Zubat","PoisonFlying","245","40","45","35","30","40","55"\n"042","Golbat","PoisonFlying","455","75","80","70","65","75","90"\n"043","Oddish","GrassPoison","320","45","50","55","75","65","30"\n"044","Gloom","GrassPoison","395","60","65","70","85","75","40"\n"045","Vileplume","GrassPoison","490","75","80","85","110","90","50"\n"046","Paras","BugGrass","285","35","70","55","45","55","25"\n"047","Parasect","BugGrass","405","60","95","80","60","80","30"\n"048","Venonat","BugPoison","305","60","55","50","40","55","45"\n"049","Venomoth","BugPoison","450","70","65","60","90","75","90"\n"050","Diglett","Ground","265","10","55","25","35","45","95"\n"051","Dugtrio","Ground","405","35","80","50","50","70","120"\n"052","Meowth","Normal","290","40","45","35","40","4 ...

# %%
mod_pd = raw_pd.split('\n')
mod_pd2 = []
for row in mod_pd:
    mod_pd2.append(row.replace('"','').split(','))

mod_pd2[:3]
# Out:
# [['PokedexNumber',
#   'Name',
#   'Type',
#   'Total',
#   'HP',
#   'Attack',
#   'Defense',
#   'SpecialAttack',
#   'SpecialDefense',
#   'Speed'],
#  ['001',
#   'Bulbasaur',
#   'GrassPoison',
#   '318',
#   '45',
#   '49',
#   '49',
#   '65',
#   '65',
#   '45'],
#  ['002', 'Ivysaur', 'GrassPoison', '405', '60', '62', '63', '80', '80', '60']]

# %%
mod_pd4 = []

for x in mod_pd2:
    mod_pd3 = []
    for y in x:
        if y == '':
            mod_pd3.append(-1)
        else:
            try:
                mod_pd3.append(float(y))  
            except:
                mod_pd3.append(y)

    mod_pd4.append(mod_pd3)

mod_pd4[:3]
# Out:
# [['PokedexNumber',
#   'Name',
#   'Type',
#   'Total',
#   'HP',
#   'Attack',
#   'Defense',
#   'SpecialAttack',
#   'SpecialDefense',
#   'Speed'],
#  [1.0, 'Bulbasaur', 'GrassPoison', 318.0, 45.0, 49.0, 49.0, 65.0, 65.0, 45.0],
#  [2.0, 'Ivysaur', 'GrassPoison', 405.0, 60.0, 62.0, 63.0, 80.0, 80.0, 60.0]]

# %% [markdown]
# <img src="http://imgur.com/gGrau8s.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ### 8.2 Parse the raw pokedex with list comprehensions
#
# ---
#
# Perform the same parsing as above, but **using only a single list comprehension** instead of for loops. You may have nested list comprehensions within the main list comprehension! The output should be exactly the same.

# %%
# Example output (first 3 sublists):
#
# ['PokedexNumber', 'Name', 'Type', 'Total', 'HP', 'Attack', 'Defense', 'SpecialAttack', 'SpecialDefense', 'Speed']
# [1.0, 'Bulbasaur', 'GrassPoison', 318.0, 45.0, 49.0, 49.0, 65.0, 65.0, 45.0]
# [2.0, 'Ivysaur', 'GrassPoison', 405.0, 60.0, 62.0, 63.0, 80.0, 80.0, 60.0]

new_pd = [[-1 if x == '' else float(x) if x.isdigit() else x for x in y] for y in [x.replace('"','').split(',') for x in raw_pd.split('\n')]]

new_pd[:3]
# Out:
# [['PokedexNumber',
#   'Name',
#   'Type',
#   'Total',
#   'HP',
#   'Attack',
#   'Defense',
#   'SpecialAttack',
#   'SpecialDefense',
#   'Speed'],
#  [1.0, 'Bulbasaur', 'GrassPoison', 318.0, 45.0, 49.0, 49.0, 65.0, 65.0, 45.0],
#  [2.0, 'Ivysaur', 'GrassPoison', 405.0, 60.0, 62.0, 63.0, 80.0, 80.0, 60.0]]

# %% [markdown]
# <img src="http://imgur.com/GCAf1UX.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 9. Write a function to generate the full pokedex
#
# ---
#
# Write a function that recreates the pokedex you made before, but with the data read in from the full pokemon file. The `PokedexNumber` should be used as the `pokemon_id` key values for the dictionary of pokemon.
#
# Your function should:
#
# 1. Take the parsed pokedex information you created above as an argument.
# 2. Return a dictionary in the same format as your original pokedex you created before containing the information from the parsed full pokedex file.
#
# To test the function, print out the pokemon with id = 100.

# %%
# Example output:
#
# {'Attack': 30.0,
#  'Defense': 50.0,
#  'HP': 40.0,
#  'Name': 'Voltorb',
#  'SpecialAttack': 55.0,
#  'SpecialDefense': 55.0,
#  'Speed': 100.0,
#  'Total': 330.0,
#  'Type': 'Electric'}

header = new_pd[0]
data = new_pd[1:]

outer_dict = {}

for row in data:
    inner_dict = {}
    for index in range(1,len(row)):
        inner_dict[header[index]] = row[index]
    outer_dict[row[0]] = inner_dict

outer_dict
# Out:
# {-1: {},
#  1.0: {'Attack': 49.0,
#   'Defense': 49.0,
#   'HP': 45.0,
#   'Name': 'Bulbasaur',
#   'SpecialAttack': 65.0,
#   'SpecialDefense': 65.0,
#   'Speed': 45.0,
#   'Total': 318.0,
#   'Type': 'GrassPoison'},
#  2.0: {'Attack': 62.0,
#   'Defense': 63.0,
#   'HP': 60.0,
#   'Name': 'Ivysaur',
#   'SpecialAttack': 80.0,
#   'SpecialDefense': 80.0,
#   'Speed': 60.0,
#   'Total': 405.0,
#   'Type': 'GrassPoison'},
#  3.0: {'Attack': 100.0,
#   'Defense': 123.0,
#   'HP': 80.0,
#   'Name': 'VenusaurMega Venusaur',
#   'SpecialAttack': 122.0,
#   'SpecialDefense': 120.0,
#   'Speed': 80.0,
#   'Total': 625.0,
#   'Type': 'GrassPoison'},
#  4.0: {'Attack': 52.0,
#   'Defense': 43.0,
#   'HP': 39.0,
#   'Name': 'Charmander',
#   'SpecialAttack': 60.0,
#   'SpecialDefense': 50.0,
#   'Speed': 65.0,
#   'Total': 309.0,
#   'Type': 'Fire'},
#  5.0: {'Attack': 64.0,
#   'Defense': 58.0,
#   'HP': 58.0,
#   'Name': 'Charmeleon',
#   'SpecialAttack': 80.0,
#   'SpecialDefense': 65.0,
#   'Speed': 80.0,
#   'Total': 405.0,
#   'Type': 'Fire'},
#  6.0: {'Attack': 104.0,
#   'Defense': 78.0,
#   'HP': 78.0,
#   'Name': 'CharizardMega Charizard Y',
#   'SpecialAttack': 159.0,
#   'SpecialDefense': 115.0,
#   'Speed': 100.0,
#   'Total': 634.0,
#   'Type': 'FireFlying'},
#  7.0: {'Attack': 48.0,
#   'Defense': 65.0,
#   'HP': 44.0,
#   'Name': 'Squirtle',
#   'SpecialAttack': 50.0,
#   'SpecialDefense': 64.0,
#   'Speed': 43.0,
#   'Total': 314.0,
#   'Type': 'Water'},
#  8.0: {'Attack': 63.0,
#   'Defense': 80.0,
#   'HP': 59.0,
#   'Name': 'Wartortle',
#   'SpecialAttack': 65.0,
#   'SpecialDefense': 80.0,
#   'Speed': 58.0,
#   'Total': 405.0,
#   'Type': 'Water'},
#  9.0: {'Attack': 103.0,
#   'Defense': 120.0,
#   'HP': 79.0,
#   'Name': 'BlastoiseMega Blastoise',
#   'SpecialAttack': 135.0,
#   'SpecialDefense': 115.0,
#   'Speed': 78.0,
#   'Total': 630.0,
#   'Type': 'Water'},
#  10.0: {'Attack': 30.0,
#   'Defense': 35.0,
#   'HP': 45.0,
#   'Name': 'Caterpie',
#   'SpecialAttack': 20.0,
#   'SpecialDefense': 20.0,
#   'Speed': 45.0,
#   'Total': 195.0,
#   'Type': 'Bug'},
#  11.0: {'Attack': 20.0,
#   'Defense': 55.0,
#   'HP': 50.0,
#   'Name': 'Metapod',
#   'SpecialAttack': 25.0,
#   'SpecialDefense': 25.0,
#   'Speed': 30.0,
#   'Total': 205.0,
#   'Type': 'Bug'},
#  12.0: {'Attack': 45.0,
#   'Defense': 50.0,
#   'HP': 60.0,
#   'Name': 'Butterfree',
#   'SpecialAttack': 90.0,
#   'SpecialDefense': 80.0,
#   'Speed': 70.0,
#   'Total': 395.0,
#   'Type': 'BugFlying'},
#  13.0: {'Attack': 35.0,
#   'Defense': 30.0,
#   'HP': 40.0,
#   'Name': 'Weedle',
#   'SpecialAttack': 20.0,
#   'SpecialDefense': 20.0,
#   'Speed': 50.0,
#   'Total': 195.0,
#   'Type': 'BugPoison'},
#  14.0: {'Attack': 25.0,
#   'Defense': 50.0,
#   'HP': 45.0,
#   'Name': 'Kakuna',
#   'SpecialAttack': 25.0,
#   'SpecialDefense': 25.0,
#   'Speed': 35.0,
#   'Total': 205.0,
#   'Type': 'BugPoison'},
#  15.0: {'Attack': 150.0,
#   'Defense': 40.0,
#   'HP': 65.0,
#   'Name': 'BeedrillMega Beedrill',
#   'SpecialAttack': 15.0,
#   'SpecialDefense': 80.0,
#   'Speed': 145.0,
#   'Total': 495.0,
#   'Type': 'BugPoison'},
#  16.0: {'Attack': 45.0,
#   'Defense': 40.0,
#   'HP': 40.0,
#   'Name': 'Pidgey',
#   'SpecialAttack': 35.0,
#   'SpecialDefense': 35.0,
#   'Speed': 56.0,
#   'Total': 251.0,
#   'Type': 'NormalFlying'},
#  17.0: {'Attack': 60.0,
#   'Defense': 55.0,
#   'HP': 63.0,
#   'Name': 'Pidgeotto',
#   'SpecialAttack': 50.0,
#   'SpecialDefense': 50.0,
#   'Speed': 71.0,
#   'Total': 349.0,
#   'Type': 'NormalFlying'},
#  18.0: {'Attack': 80.0,
#   'Defense': 80.0,
#   'HP': 83.0,
#   'Name': 'PidgeotMega Pidgeot',
#   'SpecialAttack': 135.0,
#   'SpecialDefense': 80.0,
#   'Speed': 121.0,
#   'Total': 579.0,
#   'Type': 'NormalFlying'},
#  19.0: {'Attack': 56.0,
#   'Defense': 35.0,
#   'HP': 30.0,
#   'Name': 'Rattata',
#   'SpecialAttack': 25.0,
#   'SpecialDefense': 35.0,
#   'Speed': 72.0,
#   'Total': 253.0,
#   'Type': 'Normal'},
#  20.0: {'Attack': 81.0,
#   'Defense': 60.0,
#   'HP': 55.0,
#   'Name': 'Raticate',
#   'SpecialAttack': 50.0,
#   'SpecialDefense': 70.0,
#   'Speed': 97.0,
#   'Total': 413.0,
#   'Type': 'Normal'},
#  21.0: {'Attack': 60.0,
#   'Defense': 30.0,
#   'HP': 40.0,
#   'Name': 'Spearow',
#   'SpecialAttack': 31.0,
#   'SpecialDefense': 31.0,
#   'Speed': 70.0,
#   'Total': 262.0,
#   'Type': 'NormalFlying'},
#  22.0: {'Attack': 90.0,
#   'Defense': 65.0,
#   'HP': 65.0,
#   'Name': 'Fearow',
#   'SpecialAttack': 61.0,
#   'SpecialDefense': 61.0,
#   'Speed': 100.0,
#   'Total': 442.0,
#   'Type': 'NormalFlying'},
#  23.0: {'Attack': 60.0,
#   'Defense': 44.0,
#   'HP': 35.0,
#   'Name': 'Ekans',
#   'SpecialAttack': 40.0,
#   'SpecialDefense': 54.0,
#   'Speed': 55.0,
#   'Total': 288.0,
#   'Type': 'Poison'},
#  24.0: {'Attack': 85.0,
#   'Defense': 69.0,
#   'HP': 60.0,
#   'Name': 'Arbok',
#   'SpecialAttack': 65.0,
#   'SpecialDefense': 79.0,
#   'Speed': 80.0,
#   'Total': 438.0,
#   'Type': 'Poison'},
#  25.0: {'Attack': 55.0,
#   'Defense': 40.0,
#   'HP': 35.0,
#   'Name': 'Pikachu',
#   'SpecialAttack': 50.0,
#   'SpecialDefense': 50.0,
#   'Speed': 90.0,
#   'Total': 320.0,
#   'Type': 'Electric'},
#  26.0: {'Attack': 90.0,
#   'Defense': 55.0,
#   'HP': 60.0,
#   'Name': 'Raichu',
#   'SpecialAttack': 90.0,
#   'SpecialDefense': 80.0,
#   'Speed': 110.0,
#   'Total': 485.0,
#   'Type': 'Electric'},
#  27.0: {'Attack': 75.0,
#   'Defense': 85.0,
#   'HP': 50.0,
#   'Name': 'Sandshrew',
#   'SpecialAttack': 20.0,
#   'SpecialDefense': 30.0,
#   'Speed': 40.0,
#   'Total': 300.0,
#   'Type': 'Ground'},
#  28.0: {'Attack': 100.0,
#   'Defense': 110.0,
#   'HP': 75.0,
#   'Name': 'Sandslash',
#   'SpecialAttack': 45.0,
#   'SpecialDefense': 55.0,
#   'Speed': 65.0,
#   'Total': 450.0,
#   'Type': 'Ground'},
#  29.0: {'Attack': 47.0,
#   'Defense': 52.0,
#   'HP': 55.0,
#   'Name': 'Nidoran\xe2\x99\x80',
#   'SpecialAttack': 40.0,
#   'SpecialDefense': 40.0,
#   'Speed': 41.0,
#   'Total': 275.0,
#   'Type': 'Poison'},
#  30.0: {'Attack': 62.0,
#   'Defense': 67.0,
#   'HP': 70.0,
#   'Name': 'Nidorina',
#   'SpecialAttack': 55.0,
#   'SpecialDefense': 55.0,
#   'Speed': 56.0,
#   'Total': 365.0,
#   'Type': 'Poison'},
#  31.0: {'Attack': 92.0,
#   'Defense': 87.0,
#   'HP': 90.0,
#   'Name': 'Nidoqueen',
#   'SpecialAttack': 75.0,
#   'SpecialDefense': 85.0,
#   'Speed': 76.0,
#   'Total': 505.0,
#   'Type': 'PoisonGround'},
#  32.0: {'Attack': 57.0,
#   'Defense': 40.0,
#   'HP': 46.0,
#   'Name': 'Nidoran\xe2\x99\x82',
#   'SpecialAttack': 40.0,
#   'SpecialDefense': 40.0,
#   'Speed': 50.0,
#   'Total': 273.0,
#   'Type': 'Poison'},
#  33.0: {'Attack': 72.0,
#   'Defense': 57.0,
#   'HP': 61.0,
#   'Name': 'Nidorino',
#   'SpecialAttack': 55.0,
#   'SpecialDefense': 55.0,
#   'Speed': 65.0,
#   'Total': 365.0,
#   'Type': 'Poison'},
#  34.0: {'Attack': 102.0,
#   'Defense': 77.0,
#   'HP': 81.0,
#   'Name': 'Nidoking',
#   'SpecialAttack': 85.0,
#   'SpecialDefense': 75.0,
#   'Speed': 85.0,
#   'Total': 505.0,
#   'Type': 'PoisonGround'},
#  35.0: {'Attack': 45.0,
#   'Defense': 48.0,
#   'HP': 70.0,
#   'Name': 'Clefairy',
#   'SpecialAttack': 60.0,
#   'SpecialDefense': 65.0,
#   'Speed': 35.0,
#   'Total': 323.0,
#   'Type': 'Fairy'},
#  36.0: {'Attack': 70.0,
#   'Defense': 73.0,
#   'HP': 95.0,
#   'Name': 'Clefable',
#   'SpecialAttack': 95.0,
#   'SpecialDefense': 90.0,
#   'Speed': 60.0,
#   'Total': 483.0,
#   'Type': 'Fairy'},
#  37.0: {'Attack': 41.0,
#   'Defense': 40.0,
#   'HP': 38.0,
#   'Name': 'Vulpix',
#   'SpecialAttack': 50.0,
#   'SpecialDefense': 65.0,
#   'Speed': 65.0,
#   'Total': 299.0,
#   'Type': 'Fire'},
#  38.0: {'Attack': 76.0,
#   'Defense': 75.0,
#   'HP': 73.0,
#   'Name': 'Ninetales',
#   'SpecialAttack': 81.0,
#   'SpecialDefense': 100.0,
#   'Speed': 100.0,
#   'Total': 505.0,
#   'Type': 'Fire'},
#  39.0: {'Attack': 45.0,
#   'Defense': 20.0,
#   'HP': 115.0,
#   'Name': 'Jigglypuff',
#   'SpecialAttack': 45.0,
#   'SpecialDefense': 25.0,
#   'Speed': 20.0,
#   'Total': 270.0,
#   'Type': 'NormalFairy'},
#  40.0: {'Attack': 70.0,
#   'Defense': 45.0,
#   'HP': 140.0,
#   'Name': 'Wigglytuff',
#   'SpecialAttack': 85.0,
#   'SpecialDefense': 50.0,
#   'Speed': 45.0,
#   'Total': 435.0,
#   'Type': 'NormalFairy'},
#  41.0: {'Attack': 45.0,
#   'Defense': 35.0,
#   'HP': 40.0,
#   'Name': 'Zubat',
#   'SpecialAttack': 30.0,
#   'SpecialDefense': 40.0,
#   'Speed': 55.0,
#   'Total': 245.0,
#   'Type': 'PoisonFlying'},
#  42.0: {'Attack': 80.0,
#   'Defense': 70.0,
#   'HP': 75.0,
#   'Name': 'Golbat',
#   'SpecialAttack': 65.0,
#   'SpecialDefense': 75.0,
#   'Speed': 90.0,
#   'Total': 455.0,
#   'Type': 'PoisonFlying'},
#  43.0: {'Attack': 50.0,
#   'Defense': 55.0,
#   'HP': 45.0,
#   'Name': 'Oddish',
#   'SpecialAttack': 75.0,
#   'SpecialDefense': 65.0,
#   'Speed': 30.0,
#   'Total': 320.0,
#   'Type': 'GrassPoison'},
#  44.0: {'Attack': 65.0,
#   'Defense': 70.0,
#   'HP': 60.0,
#   'Name': 'Gloom',
#   'SpecialAttack': 85.0,
#   'SpecialDefense': 75.0,
#   'Speed': 40.0,
#   'Total': 395.0,
#   'Type': 'GrassPoison'},
#  45.0: {'Attack': 80.0,
#   'Defense': 85.0,
#   'HP': 75.0,
#   'Name': 'Vileplume',
#   'SpecialAttack': 110.0,
#   'SpecialDefense': 90.0,
#   'Speed': 50.0,
#   'Total': 490.0,
#   'Type': 'GrassPoison'},
#  46.0: {'Attack': 70.0,
#   'Defense': 55.0,
#   'HP': 35.0,
#   'Name': 'Paras',
#   'SpecialAttack': 45.0,
#   'SpecialDefense': 55.0,
#   'Speed': 25.0,
#   'Total': 285.0,
#   'Type': 'BugGrass'},
#  47.0: {'Attack': 95.0,
#   'Defense': 80.0,
#   'HP': 60.0,
#   'Name': 'Parasect',
#   'SpecialAttack': 60.0,
#   'SpecialDefense': 80.0,
#   'Speed': 30.0,
#   'Total': 405.0,
#   'Type': 'BugGrass'},
#  48.0: {'Attack': 55.0,
#   'Defense': 50.0,
#   'HP': 60.0,
#   'Name': 'Venonat',
#   'SpecialAttack': 40.0,
#   'SpecialDefense': 55.0,
#   'Speed': 45.0,
#   'Total': 305.0,
#   'Type': 'BugPoison'},
#  49.0: {'Attack': 65.0,
#   'Defense': 60.0,
#   'HP': 70.0,
#   'Name': 'Venomoth',
#   'SpecialAttack': 90.0,
#   'SpecialDefense': 75.0,
#   'Speed': 90.0,
#   'Total': 450.0,
#   'Type': 'BugPoison'},
#  50.0: {'Attack': 55.0,
#   'Defense': 25.0,
#   'HP': 10.0,
#   'Name': 'Diglett',
#   'SpecialAttack': 35.0,
#   'SpecialDefense': 45.0,
#   'Speed': 95.0,
#   'Total': 265.0,
#   'Type': 'Ground'},
#  51.0: {'Attack': 80.0,
#   'Defense': 50.0,
#   'HP': 35.0,
#   'Name': 'Dugtrio',
#   'SpecialAttack': 50.0,
#   'SpecialDefense': 70.0,
#   'Speed': 120.0,
#   'Total': 405.0,
#   'Type': 'Ground'},
#  52.0: {'Attack': 45.0,
#   'Defense': 35.0,
#   'HP': 40.0,
#   'Name': 'Meowth',
#   'SpecialAttack': 40.0,
#   'SpecialDefense': 40.0,
#   'Speed': 90.0,
#   'Total': 290.0,
#   'Type': 'Normal'},
#  53.0: {'Attack': 70.0,
#   'Defense': 60.0,
#   'HP': 65.0,
#   'Name': 'Persian',
#   'SpecialAttack': 65.0,
#   'SpecialDefense': 65.0,
#   'Speed': 115.0,
#   'Total': 440.0,
#   'Type': 'Normal'},
#  54.0: {'Attack': 52.0,
#   'Defense': 48.0,
#   'HP': 50.0,
#   'Name': 'Psyduck',
#   'SpecialAttack': 65.0,
#   'SpecialDefense': 50.0,
#   'Speed': 55.0,
#   'Total': 320.0,
#   'Type': 'Water'},
#  55.0: {'Attack': 82.0,
#   'Defense': 78.0,
#   'HP': 80.0,
#   'Name': 'Golduck',
#   'SpecialAttack': 95.0,
#   'SpecialDefense': 80.0,
#   'Speed': 85.0,
#   'Total': 500.0,
#   'Type': 'Water'},
#  56.0: {'Attack': 80.0,
#   'Defense': 35.0,
#   'HP': 40.0,
#   'Name': 'Mankey',
#   'SpecialAttack': 35.0,
#   'SpecialDefense': 45.0,
#   'Speed': 70.0,
#   'Total': 305.0,
#   'Type': 'Fighting'},
#  57.0: {'Attack': 105.0,
#   'Defense': 60.0,
#   'HP': 65.0,
#   'Name': 'Primeape',
#   'SpecialAttack': 60.0,
#   'SpecialDefense': 70.0,
#   'Speed': 95.0,
#   'Total': 455.0,
#   'Type': 'Fighting'},
#  58.0: {'Attack': 70.0,
#   'Defense': 45.0,
#   'HP': 55.0,
#   'Name': 'Growlithe',
#   'SpecialAttack': 70.0,
#   'SpecialDefense': 50.0,
#   'Speed': 60.0,
#   'Total': 350.0,
#   'Type': 'Fire'},
#  59.0: {'Attack': 110.0,
#   'Defense': 80.0,
#   'HP': 90.0,
#   'Name': 'Arcanine',
#   'SpecialAttack': 100.0,
#   'SpecialDefense': 80.0,
#   'Speed': 95.0,
#   'Total': 555.0,
#   'Type': 'Fire'},
#  60.0: {'Attack': 50.0,
#   'Defense': 40.0,
#   'HP': 40.0,
#   'Name': 'Poliwag',
#   'SpecialAttack': 40.0,
#   'SpecialDefense': 40.0,
#   'Speed': 90.0,
#   'Total': 300.0,
#   'Type': 'Water'},
#  61.0: {'Attack': 65.0,
#   'Defense': 65.0,
#   'HP': 65.0,
#   'Name': 'Poliwhirl',
#   'SpecialAttack': 50.0,
#   'SpecialDefense': 50.0,
#   'Speed': 90.0,
#   'Total': 385.0,
#   'Type': 'Water'},
#  62.0: {'Attack': 95.0,
#   'Defense': 95.0,
#   'HP': 90.0,
#   'Name': 'Poliwrath',
#   'SpecialAttack': 70.0,
#   'SpecialDefense': 90.0,
#   'Speed': 70.0,
#   'Total': 510.0,
#   'Type': 'WaterFighting'},
#  63.0: {'Attack': 20.0,
#   'Defense': 15.0,
#   'HP': 25.0,
#   'Name': 'Abra',
#   'SpecialAttack': 105.0,
#   'SpecialDefense': 55.0,
#   'Speed': 90.0,
#   'Total': 310.0,
#   'Type': 'Psychic'},
#  64.0: {'Attack': 35.0,
#   'Defense': 30.0,
#   'HP': 40.0,
#   'Name': 'Kadabra',
#   'SpecialAttack': 120.0,
#   'SpecialDefense': 70.0,
#   'Speed': 105.0,
#   'Total': 400.0,
#   'Type': 'Psychic'},
#  65.0: {'Attack': 50.0,
#   'Defense': 65.0,
#   'HP': 55.0,
#   'Name': 'AlakazamMega Alakazam',
#   'SpecialAttack': 175.0,
#   'SpecialDefense': 95.0,
#   'Speed': 150.0,
#   'Total': 590.0,
#   'Type': 'Psychic'},
#  66.0: {'Attack': 80.0,
#   'Defense': 50.0,
#   'HP': 70.0,
#   'Name': 'Machop',
#   'SpecialAttack': 35.0,
#   'SpecialDefense': 35.0,
#   'Speed': 35.0,
#   'Total': 305.0,
#   'Type': 'Fighting'},
#  67.0: {'Attack': 100.0,
#   'Defense': 70.0,
#   'HP': 80.0,
#   'Name': 'Machoke',
#   'SpecialAttack': 50.0,
#   'SpecialDefense': 60.0,
#   'Speed': 45.0,
#   'Total': 405.0,
#   'Type': 'Fighting'},
#  68.0: {'Attack': 130.0,
#   'Defense': 80.0,
#   'HP': 90.0,
#   'Name': 'Machamp',
#   'SpecialAttack': 65.0,
#   'SpecialDefense': 85.0,
#   'Speed': 55.0,
#   'Total': 505.0,
#   'Type': 'Fighting'},
#  69.0: {'Attack': 75.0,
#   'Defense': 35.0,
#   'HP': 50.0,
#   'Name': 'Bellsprout',
#   'SpecialAttack': 70.0,
#   'SpecialDefense': 30.0,
#   'Speed': 40.0,
#   'Total': 300.0,
#   'Type': 'GrassPoison'},
#  70.0: {'Attack': 90.0,
#   'Defense': 50.0,
#   'HP': 65.0,
#   'Name': 'Weepinbell',
#   'SpecialAttack': 85.0,
#   'SpecialDefense': 45.0,
#   'Speed': 55.0,
#   'Total': 390.0,
#   'Type': 'GrassPoison'},
#  71.0: {'Attack': 105.0,
#   'Defense': 65.0,
#   'HP': 80.0,
#   'Name': 'Victreebel',
#   'SpecialAttack': 100.0,
#   'SpecialDefense': 70.0,
#   'Speed': 70.0,
#   'Total': 490.0,
#   'Type': 'GrassPoison'},
#  72.0: {'Attack': 40.0,
#   'Defense': 35.0,
#   'HP': 40.0,
#   'Name': 'Tentacool',
#   'SpecialAttack': 50.0,
#   'SpecialDefense': 100.0,
#   'Speed': 70.0,
#   'Total': 335.0,
#   'Type': 'WaterPoison'},
#  73.0: {'Attack': 70.0,
#   'Defense': 65.0,
#   'HP': 80.0,
#   'Name': 'Tentacruel',
#   'SpecialAttack': 80.0,
#   'SpecialDefense': 120.0,
#   'Speed': 100.0,
#   'Total': 515.0,
#   'Type': 'WaterPoison'},
#  74.0: {'Attack': 80.0,
#   'Defense': 100.0,
#   'HP': 40.0,
#   'Name': 'Geodude',
#   'SpecialAttack': 30.0,
#   'SpecialDefense': 30.0,
#   'Speed': 20.0,
#   'Total': 300.0,
#   'Type': 'RockGround'},
#  75.0: {'Attack': 95.0,
#   'Defense': 115.0,
#   'HP': 55.0,
#   'Name': 'Graveler',
#   'SpecialAttack': 45.0,
#   'SpecialDefense': 45.0,
#   'Speed': 35.0,
#   'Total': 390.0,
#   'Type': 'RockGround'},
#  76.0: {'Attack': 120.0,
#   'Defense': 130.0,
#   'HP': 80.0,
#   'Name': 'Golem',
#   'SpecialAttack': 55.0,
#   'SpecialDefense': 65.0,
#   'Speed': 45.0,
#   'Total': 495.0,
#   'Type': 'RockGround'},
#  77.0: {'Attack': 85.0,
#   'Defense': 55.0,
#   'HP': 50.0,
#   'Name': 'Ponyta',
#   'SpecialAttack': 65.0,
#   'SpecialDefense': 65.0,
#   'Speed': 90.0,
#   'Total': 410.0,
#   'Type': 'Fire'},
#  78.0: {'Attack': 100.0,
#   'Defense': 70.0,
#   'HP': 65.0,
#   'Name': 'Rapidash',
#   'SpecialAttack': 80.0,
#   'SpecialDefense': 80.0,
#   'Speed': 105.0,
#   'Total': 500.0,
#   'Type': 'Fire'},
#  79.0: {'Attack': 65.0,
#   'Defense': 65.0,
#   'HP': 90.0,
#   'Name': 'Slowpoke',
#   'SpecialAttack': 40.0,
#   'SpecialDefense': 40.0,
#   'Speed': 15.0,
#   'Total': 315.0,
#   'Type': 'WaterPsychic'},
#  80.0: {'Attack': 75.0,
#   'Defense': 180.0,
#   'HP': 95.0,
#   'Name': 'SlowbroMega Slowbro',
#   'SpecialAttack': 130.0,
#   'SpecialDefense': 80.0,
#   'Speed': 30.0,
#   'Total': 590.0,
#   'Type': 'WaterPsychic'},
#  81.0: {'Attack': 35.0,
#   'Defense': 70.0,
#   'HP': 25.0,
#   'Name': 'Magnemite',
#   'SpecialAttack': 95.0,
#   'SpecialDefense': 55.0,
#   'Speed': 45.0,
#   'Total': 325.0,
#   'Type': 'ElectricSteel'},
#  82.0: {'Attack': 60.0,
#   'Defense': 95.0,
#   'HP': 50.0,
#   'Name': 'Magneton',
#   'SpecialAttack': 120.0,
#   'SpecialDefense': 70.0,
#   'Speed': 70.0,
#   'Total': 465.0,
#   'Type': 'ElectricSteel'},
#  83.0: {'Attack': 65.0,
#   'Defense': 55.0,
#   'HP': 52.0,
#   'Name': "Farfetch'd",
#   'SpecialAttack': 58.0,
#   'SpecialDefense': 62.0,
#   'Speed': 60.0,
#   'Total': 352.0,
#   'Type': 'NormalFlying'},
#  84.0: {'Attack': 85.0,
#   'Defense': 45.0,
#   'HP': 35.0,
#   'Name': 'Doduo',
#   'SpecialAttack': 35.0,
#   'SpecialDefense': 35.0,
#   'Speed': 75.0,
#   'Total': 310.0,
#   'Type': 'NormalFlying'},
#  85.0: {'Attack': 110.0,
#   'Defense': 70.0,
#   'HP': 60.0,
#   'Name': 'Dodrio',
#   'SpecialAttack': 60.0,
#   'SpecialDefense': 60.0,
#   'Speed': 100.0,
#   'Total': 460.0,
#   'Type': 'NormalFlying'},
#  86.0: {'Attack': 45.0,
#   'Defense': 55.0,
#   'HP': 65.0,
#   'Name': 'Seel',
#   'SpecialAttack': 45.0,
#   'SpecialDefense': 70.0,
#   'Speed': 45.0,
#   'Total': 325.0,
#   'Type': 'Water'},
#  87.0: {'Attack': 70.0,
#   'Defense': 80.0,
#   'HP': 90.0,
#   'Name': 'Dewgong',
#   'SpecialAttack': 70.0,
#   'SpecialDefense': 95.0,
#   'Speed': 70.0,
#   'Total': 475.0,
#   'Type': 'WaterIce'},
#  88.0: {'Attack': 80.0,
#   'Defense': 50.0,
#   'HP': 80.0,
#   'Name': 'Grimer',
#   'SpecialAttack': 40.0,
#   'SpecialDefense': 50.0,
#   'Speed': 25.0,
#   'Total': 325.0,
#   'Type': 'Poison'},
#  89.0: {'Attack': 105.0,
#   'Defense': 75.0,
#   'HP': 105.0,
#   'Name': 'Muk',
#   'SpecialAttack': 65.0,
#   'SpecialDefense': 100.0,
#   'Speed': 50.0,
#   'Total': 500.0,
#   'Type': 'Poison'},
#  90.0: {'Attack': 65.0,
#   'Defense': 100.0,
#   'HP': 30.0,
#   'Name': 'Shellder',
#   'SpecialAttack': 45.0,
#   'SpecialDefense': 25.0,
#   'Speed': 40.0,
#   'Total': 305.0,
#   'Type': 'Water'},
#  91.0: {'Attack': 95.0,
#   'Defense': 180.0,
#   'HP': 50.0,
#   'Name': 'Cloyster',
#   'SpecialAttack': 85.0,
#   'SpecialDefense': 45.0,
#   'Speed': 70.0,
#   'Total': 525.0,
#   'Type': 'WaterIce'},
#  92.0: {'Attack': 35.0,
#   'Defense': 30.0,
#   'HP': 30.0,
#   'Name': 'Gastly',
#   'SpecialAttack': 100.0,
#   'SpecialDefense': 35.0,
#   'Speed': 80.0,
#   'Total': 310.0,
#   'Type': 'GhostPoison'},
#  93.0: {'Attack': 50.0,
#   'Defense': 45.0,
#   'HP': 45.0,
#   'Name': 'Haunter',
#   'SpecialAttack': 115.0,
#   'SpecialDefense': 55.0,
#   'Speed': 95.0,
#   'Total': 405.0,
#   'Type': 'GhostPoison'},
#  94.0: {'Attack': 65.0,
#   'Defense': 80.0,
#   'HP': 60.0,
#   'Name': 'GengarMega Gengar',
#   'SpecialAttack': 170.0,
#   'SpecialDefense': 95.0,
#   'Speed': 130.0,
#   'Total': 600.0,
#   'Type': 'GhostPoison'},
#  95.0: {'Attack': 45.0,
#   'Defense': 160.0,
#   'HP': 35.0,
#   'Name': 'Onix',
#   'SpecialAttack': 30.0,
#   'SpecialDefense': 45.0,
#   'Speed': 70.0,
#   'Total': 385.0,
#   'Type': 'RockGround'},
#  96.0: {'Attack': 48.0,
#   'Defense': 45.0,
#   'HP': 60.0,
#   'Name': 'Drowzee',
#   'SpecialAttack': 43.0,
#   'SpecialDefense': 90.0,
#   'Speed': 42.0,
#   'Total': 328.0,
#   'Type': 'Psychic'},
#  97.0: {'Attack': 73.0,
#   'Defense': 70.0,
#   'HP': 85.0,
#   'Name': 'Hypno',
#   'SpecialAttack': 73.0,
#   'SpecialDefense': 115.0,
#   'Speed': 67.0,
#   'Total': 483.0,
#   'Type': 'Psychic'},
#  98.0: {'Attack': 105.0,
#   'Defense': 90.0,
#   'HP': 30.0,
#   'Name': 'Krabby',
#   'SpecialAttack': 25.0,
#   'SpecialDefense': 25.0,
#   'Speed': 50.0,
#   'Total': 325.0,
#   'Type': 'Water'},
#  99.0: {'Attack': 130.0,
#   'Defense': 115.0,
#   'HP': 55.0,
#   'Name': 'Kingler',
#   'SpecialAttack': 50.0,
#   'SpecialDefense': 50.0,
#   'Speed': 75.0,
#   'Total': 475.0,
#   'Type': 'Water'},
#  100.0: {'Attack': 30.0,
#   'Defense': 50.0,
#   'HP': 40.0,
#   'Name': 'Voltorb',
#   'SpecialAttack': 55.0,
#   'SpecialDefense': 55.0,
#   'Speed': 100.0,
#   'Total': 330.0,
#   'Type': 'Electric'},
#  101.0: {'Attack': 50.0,
#   'Defense': 70.0,
#   'HP': 60.0,
#   'Name': 'Electrode',
#   'SpecialAttack': 80.0,
#   'SpecialDefense': 80.0,
#   'Speed': 140.0,
#   'Total': 480.0,
#   'Type': 'Electric'},
#  102.0: {'Attack': 40.0,
#   'Defense': 80.0,
#   'HP': 60.0,
#   'Name': 'Exeggcute',
#   'SpecialAttack': 60.0,
#   'SpecialDefense': 45.0,
#   'Speed': 40.0,
#   'Total': 325.0,
#   'Type': 'GrassPsychic'},
#  103.0: {'Attack': 95.0,
#   'Defense': 85.0,
#   'HP': 95.0,
#   'Name': 'Exeggutor',
#   'SpecialAttack': 125.0,
#   'SpecialDefense': 65.0,
#   'Speed': 55.0,
#   'Total': 520.0,
#   'Type': 'GrassPsychic'},
#  104.0: {'Attack': 50.0,
#   'Defense': 95.0,
#   'HP': 50.0,
#   'Name': 'Cubone',
#   'SpecialAttack': 40.0,
#   'SpecialDefense': 50.0,
#   'Speed': 35.0,
#   'Total': 320.0,
#   'Type': 'Ground'},
#  105.0: {'Attack': 80.0,
#   'Defense': 110.0,
#   'HP': 60.0,
#   'Name': 'Marowak',
#   'SpecialAttack': 50.0,
#   'SpecialDefense': 80.0,
#   'Speed': 45.0,
#   'Total': 425.0,
#   'Type': 'Ground'},
#  106.0: {'Attack': 120.0,
#   'Defense': 53.0,
#   'HP': 50.0,
#   'Name': 'Hitmonlee',
#   'SpecialAttack': 35.0,
#   'SpecialDefense': 110.0,
#   'Speed': 87.0,
#   'Total': 455.0,
#   'Type': 'Fighting'},
#  107.0: {'Attack': 105.0,
#   'Defense': 79.0,
#   'HP': 50.0,
#   'Name': 'Hitmonchan',
#   'SpecialAttack': 35.0,
#   'SpecialDefense': 110.0,
#   'Speed': 76.0,
#   'Total': 455.0,
#   'Type': 'Fighting'},
#  108.0: {'Attack': 55.0,
#   'Defense': 75.0,
#   'HP': 90.0,
#   'Name': 'Lickitung',
#   'SpecialAttack': 60.0,
#   'SpecialDefense': 75.0,
#   'Speed': 30.0,
#   'Total': 385.0,
#   'Type': 'Normal'},
#  109.0: {'Attack': 65.0,
#   'Defense': 95.0,
#   'HP': 40.0,
#   'Name': 'Koffing',
#   'SpecialAttack': 60.0,
#   'SpecialDefense': 45.0,
#   'Speed': 35.0,
#   'Total': 340.0,
#   'Type': 'Poison'},
#  110.0: {'Attack': 90.0,
#   'Defense': 120.0,
#   'HP': 65.0,
#   'Name': 'Weezing',
#   'SpecialAttack': 85.0,
#   'SpecialDefense': 70.0,
#   'Speed': 60.0,
#   'Total': 490.0,
#   'Type': 'Poison'},
#  111.0: {'Attack': 85.0,
#   'Defense': 95.0,
#   'HP': 80.0,
#   'Name': 'Rhyhorn',
#   'SpecialAttack': 30.0,
#   'SpecialDefense': 30.0,
#   'Speed': 25.0,
#   'Total': 345.0,
#   'Type': 'GroundRock'},
#  112.0: {'Attack': 130.0,
#   'Defense': 120.0,
#   'HP': 105.0,
#   'Name': 'Rhydon',
#   'SpecialAttack': 45.0,
#   'SpecialDefense': 45.0,
#   'Speed': 40.0,
#   'Total': 485.0,
#   'Type': 'GroundRock'},
#  113.0: {'Attack': 5.0,
#   'Defense': 5.0,
#   'HP': 250.0,
#   'Name': 'Chansey',
#   'SpecialAttack': 35.0,
#   'SpecialDefense': 105.0,
#   'Speed': 50.0,
#   'Total': 450.0,
#   'Type': 'Normal'},
#  114.0: {'Attack': 55.0,
#   'Defense': 115.0,
#   'HP': 65.0,
#   'Name': 'Tangela',
#   'SpecialAttack': 100.0,
#   'SpecialDefense': 40.0,
#   'Speed': 60.0,
#   'Total': 435.0,
#   'Type': 'Grass'},
#  115.0: {'Attack': 125.0,
#   'Defense': 100.0,
#   'HP': 105.0,
#   'Name': 'KangaskhanMega Kangaskhan',
#   'SpecialAttack': 60.0,
#   'SpecialDefense': 100.0,
#   'Speed': 100.0,
#   'Total': 590.0,
#   'Type': 'Normal'},
#  116.0: {'Attack': 40.0,
#   'Defense': 70.0,
#   'HP': 30.0,
#   'Name': 'Horsea',
#   'SpecialAttack': 70.0,
#   'SpecialDefense': 25.0,
#   'Speed': 60.0,
#   'Total': 295.0,
#   'Type': 'Water'},
#  117.0: {'Attack': 65.0,
#   'Defense': 95.0,
#   'HP': 55.0,
#   'Name': 'Seadra',
#   'SpecialAttack': 95.0,
#   'SpecialDefense': 45.0,
#   'Speed': 85.0,
#   'Total': 440.0,
#   'Type': 'Water'},
#  118.0: {'Attack': 67.0,
#   'Defense': 60.0,
#   'HP': 45.0,
#   'Name': 'Goldeen',
#   'SpecialAttack': 35.0,
#   'SpecialDefense': 50.0,
#   'Speed': 63.0,
#   'Total': 320.0,
#   'Type': 'Water'},
#  119.0: {'Attack': 92.0,
#   'Defense': 65.0,
#   'HP': 80.0,
#   'Name': 'Seaking',
#   'SpecialAttack': 65.0,
#   'SpecialDefense': 80.0,
#   'Speed': 68.0,
#   'Total': 450.0,
#   'Type': 'Water'},
#  120.0: {'Attack': 45.0,
#   'Defense': 55.0,
#   'HP': 30.0,
#   'Name': 'Staryu',
#   'SpecialAttack': 70.0,
#   'SpecialDefense': 55.0,
#   'Speed': 85.0,
#   'Total': 340.0,
#   'Type': 'Water'},
#  121.0: {'Attack': 75.0,
#   'Defense': 85.0,
#   'HP': 60.0,
#   'Name': 'Starmie',
#   'SpecialAttack': 100.0,
#   'SpecialDefense': 85.0,
#   'Speed': 115.0,
#   'Total': 520.0,
#   'Type': 'WaterPsychic'},
#  122.0: {'Attack': 45.0,
#   'Defense': 65.0,
#   'HP': 40.0,
#   'Name': 'Mr. Mime',
#   'SpecialAttack': 100.0,
#   'SpecialDefense': 120.0,
#   'Speed': 90.0,
#   'Total': 460.0,
#   'Type': 'PsychicFairy'},
#  123.0: {'Attack': 110.0,
#   'Defense': 80.0,
#   'HP': 70.0,
#   'Name': 'Scyther',
#   'SpecialAttack': 55.0,
#   'SpecialDefense': 80.0,
#   'Speed': 105.0,
#   'Total': 500.0,
#   'Type': 'BugFlying'},
#  124.0: {'Attack': 50.0,
#   'Defense': 35.0,
#   'HP': 65.0,
#   'Name': 'Jynx',
#   'SpecialAttack': 115.0,
#   'SpecialDefense': 95.0,
#   'Speed': 95.0,
#   'Total': 455.0,
#   'Type': 'IcePsychic'},
#  125.0: {'Attack': 83.0,
#   'Defense': 57.0,
#   'HP': 65.0,
#   'Name': 'Electabuzz',
#   'SpecialAttack': 95.0,
#   'SpecialDefense': 85.0,
#   'Speed': 105.0,
#   'Total': 490.0,
#   'Type': 'Electric'},
#  126.0: {'Attack': 95.0,
#   'Defense': 57.0,
#   'HP': 65.0,
#   'Name': 'Magmar',
#   'SpecialAttack': 100.0,
#   'SpecialDefense': 85.0,
#   'Speed': 93.0,
#   'Total': 495.0,
#   'Type': 'Fire'},
#  127.0: {'Attack': 155.0,
#   'Defense': 120.0,
#   'HP': 65.0,
#   'Name': 'PinsirMega Pinsir',
#   'SpecialAttack': 65.0,
#   'SpecialDefense': 90.0,
#   'Speed': 105.0,
#   'Total': 600.0,
#   'Type': 'BugFlying'},
#  128.0: {'Attack': 100.0,
#   'Defense': 95.0,
#   'HP': 75.0,
#   'Name': 'Tauros',
#   'SpecialAttack': 40.0,
#   'SpecialDefense': 70.0,
#   'Speed': 110.0,
#   'Total': 490.0,
#   'Type': 'Normal'},
#  129.0: {'Attack': 10.0,
#   'Defense': 55.0,
#   'HP': 20.0,
#   'Name': 'Magikarp',
#   'SpecialAttack': 15.0,
#   'SpecialDefense': 20.0,
#   'Speed': 80.0,
#   'Total': 200.0,
#   'Type': 'Water'},
#  130.0: {'Attack': 155.0,
#   'Defense': 109.0,
#   'HP': 95.0,
#   'Name': 'GyaradosMega Gyarados',
#   'SpecialAttack': 70.0,
#   'SpecialDefense': 130.0,
#   'Speed': 81.0,
#   'Total': 640.0,
#   'Type': 'WaterDark'},
#  131.0: {'Attack': 85.0,
#   'Defense': 80.0,
#   'HP': 130.0,
#   'Name': 'Lapras',
#   'SpecialAttack': 85.0,
#   'SpecialDefense': 95.0,
#   'Speed': 60.0,
#   'Total': 535.0,
#   'Type': 'WaterIce'},
#  132.0: {'Attack': 48.0,
#   'Defense': 48.0,
#   'HP': 48.0,
#   'Name': 'Ditto',
#   'SpecialAttack': 48.0,
#   'SpecialDefense': 48.0,
#   'Speed': 48.0,
#   'Total': 288.0,
#   'Type': 'Normal'},
#  133.0: {'Attack': 55.0,
#   'Defense': 50.0,
#   'HP': 55.0,
#   'Name': 'Eevee',
#   'SpecialAttack': 45.0,
#   'SpecialDefense': 65.0,
#   'Speed': 55.0,
#   'Total': 325.0,
#   'Type': 'Normal'},
#  134.0: {'Attack': 65.0,
#   'Defense': 60.0,
#   'HP': 130.0,
#   'Name': 'Vaporeon',
#   'SpecialAttack': 110.0,
#   'SpecialDefense': 95.0,
#   'Speed': 65.0,
#   'Total': 525.0,
#   'Type': 'Water'},
#  135.0: {'Attack': 65.0,
#   'Defense': 60.0,
#   'HP': 65.0,
#   'Name': 'Jolteon',
#   'SpecialAttack': 110.0,
#   'SpecialDefense': 95.0,
#   'Speed': 130.0,
#   'Total': 525.0,
#   'Type': 'Electric'},
#  136.0: {'Attack': 130.0,
#   'Defense': 60.0,
#   'HP': 65.0,
#   'Name': 'Flareon',
#   'SpecialAttack': 95.0,
#   'SpecialDefense': 110.0,
#   'Speed': 65.0,
#   'Total': 525.0,
#   'Type': 'Fire'},
#  137.0: {'Attack': 60.0,
#   'Defense': 70.0,
#   'HP': 65.0,
#   'Name': 'Porygon',
#   'SpecialAttack': 85.0,
#   'SpecialDefense': 75.0,
#   'Speed': 40.0,
#   'Total': 395.0,
#   'Type': 'Normal'},
#  138.0: {'Attack': 40.0,
#   'Defense': 100.0,
#   'HP': 35.0,
#   'Name': 'Omanyte',
#   'SpecialAttack': 90.0,
#   'SpecialDefense': 55.0,
#   'Speed': 35.0,
#   'Total': 355.0,
#   'Type': 'RockWater'},
#  139.0: {'Attack': 60.0,
#   'Defense': 125.0,
#   'HP': 70.0,
#   'Name': 'Omastar',
#   'SpecialAttack': 115.0,
#   'SpecialDefense': 70.0,
#   'Speed': 55.0,
#   'Total': 495.0,
#   'Type': 'RockWater'},
#  140.0: {'Attack': 80.0,
#   'Defense': 90.0,
#   'HP': 30.0,
#   'Name': 'Kabuto',
#   'SpecialAttack': 55.0,
#   'SpecialDefense': 45.0,
#   'Speed': 55.0,
#   'Total': 355.0,
#   'Type': 'RockWater'},
#  141.0: {'Attack': 115.0,
#   'Defense': 105.0,
#   'HP': 60.0,
#   'Name': 'Kabutops',
#   'SpecialAttack': 65.0,
#   'SpecialDefense': 70.0,
#   'Speed': 80.0,
#   'Total': 495.0,
#   'Type': 'RockWater'},
#  142.0: {'Attack': 135.0,
#   'Defense': 85.0,
#   'HP': 80.0,
#   'Name': 'AerodactylMega Aerodactyl',
#   'SpecialAttack': 70.0,
#   'SpecialDefense': 95.0,
#   'Speed': 150.0,
#   'Total': 615.0,
#   'Type': 'RockFlying'},
#  143.0: {'Attack': 110.0,
#   'Defense': 65.0,
#   'HP': 160.0,
#   'Name': 'Snorlax',
#   'SpecialAttack': 65.0,
#   'SpecialDefense': 110.0,
#   'Speed': 30.0,
#   'Total': 540.0,
#   'Type': 'Normal'},
#  144.0: {'Attack': 85.0,
#   'Defense': 100.0,
#   'HP': 90.0,
#   'Name': 'Articuno',
#   'SpecialAttack': 95.0,
#   'SpecialDefense': 125.0,
#   'Speed': 85.0,
#   'Total': 580.0,
#   'Type': 'IceFlying'},
#  145.0: {'Attack': 90.0,
#   'Defense': 85.0,
#   'HP': 90.0,
#   'Name': 'Zapdos',
#   'SpecialAttack': 125.0,
#   'SpecialDefense': 90.0,
#   'Speed': 100.0,
#   'Total': 580.0,
#   'Type': 'ElectricFlying'},
#  146.0: {'Attack': 100.0,
#   'Defense': 90.0,
#   'HP': 90.0,
#   'Name': 'Moltres',
#   'SpecialAttack': 125.0,
#   'SpecialDefense': 85.0,
#   'Speed': 90.0,
#   'Total': 580.0,
#   'Type': 'FireFlying'},
#  147.0: {'Attack': 64.0,
#   'Defense': 45.0,
#   'HP': 41.0,
#   'Name': 'Dratini',
#   'SpecialAttack': 50.0,
#   'SpecialDefense': 50.0,
#   'Speed': 50.0,
#   'Total': 300.0,
#   'Type': 'Dragon'},
#  148.0: {'Attack': 84.0,
#   'Defense': 65.0,
#   'HP': 61.0,
#   'Name': 'Dragonair',
#   'SpecialAttack': 70.0,
#   'SpecialDefense': 70.0,
#   'Speed': 70.0,
#   'Total': 420.0,
#   'Type': 'Dragon'},
#  149.0: {'Attack': 134.0,
#   'Defense': 95.0,
#   'HP': 91.0,
#   'Name': 'Dragonite',
#   'SpecialAttack': 100.0,
#   'SpecialDefense': 100.0,
#   'Speed': 80.0,
#   'Total': 600.0,
#   'Type': 'DragonFlying'},
#  150.0: {'Attack': 150.0,
#   'Defense': 70.0,
#   'HP': 106.0,
#   'Name': 'MewtwoMega Mewtwo Y',
#   'SpecialAttack': 194.0,
#   'SpecialDefense': 120.0,
#   'Speed': 140.0,
#   'Total': 780.0,
#   'Type': 'Psychic'},
#  151.0: {'Attack': 100.0,
#   'Defense': 100.0,
#   'HP': 100.0,
#   'Name': 'Mew',
#   'SpecialAttack': 100.0,
#   'SpecialDefense': 100.0,
#   'Speed': 100.0,
#   'Total': 600.0,
#   'Type': 'Psychic'},
#  152.0: {'Attack': 49.0,
#   'Defense': 65.0,
#   'HP': 45.0,
#   'Name': 'Chikorita',
#   'SpecialAttack': 49.0,
#   'SpecialDefense': 65.0,
#   'Speed': 45.0,
#   'Total': 318.0,
#   'Type': 'Grass'},
#  153.0: {'Attack': 62.0,
#   'Defense': 80.0,
#   'HP': 60.0,
#   'Name': 'Bayleef',
#   'SpecialAttack': 63.0,
#   'SpecialDefense': 80.0,
#   'Speed': 60.0,
#   'Total': 405.0,
#   'Type': 'Grass'},
#  154.0: {'Attack': 82.0,
#   'Defense': 100.0,
#   'HP': 80.0,
#   'Name': 'Meganium',
#   'SpecialAttack': 83.0,
#   'SpecialDefense': 100.0,
#   'Speed': 80.0,
#   'Total': 525.0,
#   'Type': 'Grass'},
#  155.0: {'Attack': 52.0,
#   'Defense': 43.0,
#   'HP': 39.0,
#   'Name': 'Cyndaquil',
#   'SpecialAttack': 60.0,
#   'SpecialDefense': 50.0,
#   'Speed': 65.0,
#   'Total': 309.0,
#   'Type': 'Fire'},
#  156.0: {'Attack': 64.0,
#   'Defense': 58.0,
#   'HP': 58.0,
#   'Name': 'Quilava',
#   'SpecialAttack': 80.0,
#   'SpecialDefense': 65.0,
#   'Speed': 80.0,
#   'Total': 405.0,
#   'Type': 'Fire'},
#  157.0: {'Attack': 84.0,
#   'Defense': 78.0,
#   'HP': 78.0,
#   'Name': 'Typhlosion',
#   'SpecialAttack': 109.0,
#   'SpecialDefense': 85.0,
#   'Speed': 100.0,
#   'Total': 534.0,
#   'Type': 'Fire'},
#  158.0: {'Attack': 65.0,
#   'Defense': 64.0,
#   'HP': 50.0,
#   'Name': 'Totodile',
#   'SpecialAttack': 44.0,
#   'SpecialDefense': 48.0,
#   'Speed': 43.0,
#   'Total': 314.0,
#   'Type': 'Water'},
#  159.0: {'Attack': 80.0,
#   'Defense': 80.0,
#   'HP': 65.0,
#   'Name': 'Croconaw',
#   'SpecialAttack': 59.0,
#   'SpecialDefense': 63.0,
#   'Speed': 58.0,
#   'Total': 405.0,
#   'Type': 'Water'},
#  160.0: {'Attack': 105.0,
#   'Defense': 100.0,
#   'HP': 85.0,
#   'Name': 'Feraligatr',
#   'SpecialAttack': 79.0,
#   'SpecialDefense': 83.0,
#   'Speed': 78.0,
#   'Total': 530.0,
#   'Type': 'Water'},
#  161.0: {'Attack': 46.0,
#   'Defense': 34.0,
#   'HP': 35.0,
#   'Name': 'Sentret',
#   'SpecialAttack': 35.0,
#   'SpecialDefense': 45.0,
#   'Speed': 20.0,
#   'Total': 215.0,
#   'Type': 'Normal'},
#  162.0: {'Attack': 76.0,
#   'Defense': 64.0,
#   'HP': 85.0,
#   'Name': 'Furret',
#   'SpecialAttack': 45.0,
#   'SpecialDefense': 55.0,
#   'Speed': 90.0,
#   'Total': 415.0,
#   'Type': 'Normal'},
#  163.0: {'Attack': 30.0,
#   'Defense': 30.0,
#   'HP': 60.0,
#   'Name': 'Hoothoot',
#   'SpecialAttack': 36.0,
#   'SpecialDefense': 56.0,
#   'Speed': 50.0,
#   'Total': 262.0,
#   'Type': 'NormalFlying'},
#  164.0: {'Attack': 50.0,
#   'Defense': 50.0,
#   'HP': 100.0,
#   'Name': 'Noctowl',
#   'SpecialAttack': 76.0,
#   'SpecialDefense': 96.0,
#   'Speed': 70.0,
#   'Total': 442.0,
#   'Type': 'NormalFlying'},
#  165.0: {'Attack': 20.0,
#   'Defense': 30.0,
#   'HP': 40.0,
#   'Name': 'Ledyba',
#   'SpecialAttack': 40.0,
#   'SpecialDefense': 80.0,
#   'Speed': 55.0,
#   'Total': 265.0,
#   'Type': 'BugFlying'},
#  166.0: {'Attack': 35.0,
#   'Defense': 50.0,
#   'HP': 55.0,
#   'Name': 'Ledian',
#   'SpecialAttack': 55.0,
#   'SpecialDefense': 110.0,
#   'Speed': 85.0,
#   'Total': 390.0,
#   'Type': 'BugFlying'},
#  167.0: {'Attack': 60.0,
#   'Defense': 40.0,
#   'HP': 40.0,
#   'Name': 'Spinarak',
#   'SpecialAttack': 40.0,
#   'SpecialDefense': 40.0,
#   'Speed': 30.0,
#   'Total': 250.0,
#   'Type': 'BugPoison'},
#  168.0: {'Attack': 90.0,
#   'Defense': 70.0,
#   'HP': 70.0,
#   'Name': 'Ariados',
#   'SpecialAttack': 60.0,
#   'SpecialDefense': 60.0,
#   'Speed': 40.0,
#   'Total': 390.0,
#   'Type': 'BugPoison'},
#  169.0: {'Attack': 90.0,
#   'Defense': 80.0,
#   'HP': 85.0,
#   'Name': 'Crobat',
#   'SpecialAttack': 70.0,
#   'SpecialDefense': 80.0,
#   'Speed': 130.0,
#   'Total': 535.0,
#   'Type': 'PoisonFlying'},
#  170.0: {'Attack': 38.0,
#   'Defense': 38.0,
#   'HP': 75.0,
#   'Name': 'Chinchou',
#   'SpecialAttack': 56.0,
#   'SpecialDefense': 56.0,
#   'Speed': 67.0,
#   'Total': 330.0,
#   'Type': 'WaterElectric'},
#  171.0: {'Attack': 58.0,
#   'Defense': 58.0,
#   'HP': 125.0,
#   'Name': 'Lanturn',
#   'SpecialAttack': 76.0,
#   'SpecialDefense': 76.0,
#   'Speed': 67.0,
#   'Total': 460.0,
#   'Type': 'WaterElectric'},
#  172.0: {'Attack': 40.0,
#   'Defense': 15.0,
#   'HP': 20.0,
#   'Name': 'Pichu',
#   'SpecialAttack': 35.0,
#   'SpecialDefense': 35.0,
#   'Speed': 60.0,
#   'Total': 205.0,
#   'Type': 'Electric'},
#  173.0: {'Attack': 25.0,
#   'Defense': 28.0,
#   'HP': 50.0,
#   'Name': 'Cleffa',
#   'SpecialAttack': 45.0,
#   'SpecialDefense': 55.0,
#   'Speed': 15.0,
#   'Total': 218.0,
#   'Type': 'Fairy'},
#  174.0: {'Attack': 30.0,
#   'Defense': 15.0,
#   'HP': 90.0,
#   'Name': 'Igglybuff',
#   'SpecialAttack': 40.0,
#   'SpecialDefense': 20.0,
#   'Speed': 15.0,
#   'Total': 210.0,
#   'Type': 'NormalFairy'},
#  175.0: {'Attack': 20.0,
#   'Defense': 65.0,
#   'HP': 35.0,
#   'Name': 'Togepi',
#   'SpecialAttack': 40.0,
#   'SpecialDefense': 65.0,
#   'Speed': 20.0,
#   'Total': 245.0,
#   'Type': 'Fairy'},
#  176.0: {'Attack': 40.0,
#   'Defense': 85.0,
#   'HP': 55.0,
#   'Name': 'Togetic',
#   'SpecialAttack': 80.0,
#   'SpecialDefense': 105.0,
#   'Speed': 40.0,
#   'Total': 405.0,
#   'Type': 'FairyFlying'},
#  177.0: {'Attack': 50.0,
#   'Defense': 45.0,
#   'HP': 40.0,
#   'Name': 'Natu',
#   'SpecialAttack': 70.0,
#   'SpecialDefense': 45.0,
#   'Speed': 70.0,
#   'Total': 320.0,
#   'Type': 'PsychicFlying'},
#  178.0: {'Attack': 75.0,
#   'Defense': 70.0,
#   'HP': 65.0,
#   'Name': 'Xatu',
#   'SpecialAttack': 95.0,
#   'SpecialDefense': 70.0,
#   'Speed': 95.0,
#   'Total': 470.0,
#   'Type': 'PsychicFlying'},
#  179.0: {'Attack': 40.0,
#   'Defense': 40.0,
#   'HP': 55.0,
#   'Name': 'Mareep',
#   'SpecialAttack': 65.0,
#   'SpecialDefense': 45.0,
#   'Speed': 35.0,
#   'Total': 280.0,
#   'Type': 'Electric'},
#  180.0: {'Attack': 55.0,
#   'Defense': 55.0,
#   'HP': 70.0,
#   'Name': 'Flaaffy',
#   'SpecialAttack': 80.0,
#   'SpecialDefense': 60.0,
#   'Speed': 45.0,
#   'Total': 365.0,
#   'Type': 'Electric'},
#  181.0: {'Attack': 95.0,
#   'Defense': 105.0,
#   'HP': 90.0,
#   'Name': 'AmpharosMega Ampharos',
#   'SpecialAttack': 165.0,
#   'SpecialDefense': 110.0,
#   'Speed': 45.0,
#   'Total': 610.0,
#   'Type': 'ElectricDragon'},
#  182.0: {'Attack': 80.0,
#   'Defense': 95.0,
#   'HP': 75.0,
#   'Name': 'Bellossom',
#   'SpecialAttack': 90.0,
#   'SpecialDefense': 100.0,
#   'Speed': 50.0,
#   'Total': 490.0,
#   'Type': 'Grass'},
#  183.0: {'Attack': 20.0,
#   'Defense': 50.0,
#   'HP': 70.0,
#   'Name': 'Marill',
#   'SpecialAttack': 20.0,
#   'SpecialDefense': 50.0,
#   'Speed': 40.0,
#   'Total': 250.0,
#   'Type': 'WaterFairy'},
#  184.0: {'Attack': 50.0,
#   'Defense': 80.0,
#   'HP': 100.0,
#   'Name': 'Azumarill',
#   'SpecialAttack': 60.0,
#   'SpecialDefense': 80.0,
#   'Speed': 50.0,
#   'Total': 420.0,
#   'Type': 'WaterFairy'},
#  185.0: {'Attack': 100.0,
#   'Defense': 115.0,
#   'HP': 70.0,
#   'Name': 'Sudowoodo',
#   'SpecialAttack': 30.0,
#   'SpecialDefense': 65.0,
#   'Speed': 30.0,
#   'Total': 410.0,
#   'Type': 'Rock'},
#  186.0: {'Attack': 75.0,
#   'Defense': 75.0,
#   'HP': 90.0,
#   'Name': 'Politoed',
#   'SpecialAttack': 90.0,
#   'SpecialDefense': 100.0,
#   'Speed': 70.0,
#   'Total': 500.0,
#   'Type': 'Water'},
#  187.0: {'Attack': 35.0,
#   'Defense': 40.0,
#   'HP': 35.0,
#   'Name': 'Hoppip',
#   'SpecialAttack': 35.0,
#   'SpecialDefense': 55.0,
#   'Speed': 50.0,
#   'Total': 250.0,
#   'Type': 'GrassFlying'},
#  188.0: {'Attack': 45.0,
#   'Defense': 50.0,
#   'HP': 55.0,
#   'Name': 'Skiploom',
#   'SpecialAttack': 45.0,
#   'SpecialDefense': 65.0,
#   'Speed': 80.0,
#   'Total': 340.0,
#   'Type': 'GrassFlying'},
#  189.0: {'Attack': 55.0,
#   'Defense': 70.0,
#   'HP': 75.0,
#   'Name': 'Jumpluff',
#   'SpecialAttack': 55.0,
#   'SpecialDefense': 95.0,
#   'Speed': 110.0,
#   'Total': 460.0,
#   'Type': 'GrassFlying'},
#  190.0: {'Attack': 70.0,
#   'Defense': 55.0,
#   'HP': 55.0,
#   'Name': 'Aipom',
#   'SpecialAttack': 40.0,
#   'SpecialDefense': 55.0,
#   'Speed': 85.0,
#   'Total': 360.0,
#   'Type': 'Normal'},
#  191.0: {'Attack': 30.0,
#   'Defense': 30.0,
#   'HP': 30.0,
#   'Name': 'Sunkern',
#   'SpecialAttack': 30.0,
#   'SpecialDefense': 30.0,
#   'Speed': 30.0,
#   'Total': 180.0,
#   'Type': 'Grass'},
#  192.0: {'Attack': 75.0,
#   'Defense': 55.0,
#   'HP': 75.0,
#   'Name': 'Sunflora',
#   'SpecialAttack': 105.0,
#   'SpecialDefense': 85.0,
#   'Speed': 30.0,
#   'Total': 425.0,
#   'Type': 'Grass'},
#  193.0: {'Attack': 65.0,
#   'Defense': 45.0,
#   'HP': 65.0,
#   'Name': 'Yanma',
#   'SpecialAttack': 75.0,
#   'SpecialDefense': 45.0,
#   'Speed': 95.0,
#   'Total': 390.0,
#   'Type': 'BugFlying'},
#  194.0: {'Attack': 45.0,
#   'Defense': 45.0,
#   'HP': 55.0,
#   'Name': 'Wooper',
#   'SpecialAttack': 25.0,
#   'SpecialDefense': 25.0,
#   'Speed': 15.0,
#   'Total': 210.0,
#   'Type': 'WaterGround'},
#  195.0: {'Attack': 85.0,
#   'Defense': 85.0,
#   'HP': 95.0,
#   'Name': 'Quagsire',
#   'SpecialAttack': 65.0,
#   'SpecialDefense': 65.0,
#   'Speed': 35.0,
#   'Total': 430.0,
#   'Type': 'WaterGround'},
#  196.0: {'Attack': 65.0,
#   'Defense': 60.0,
#   'HP': 65.0,
#   'Name': 'Espeon',
#   'SpecialAttack': 130.0,
#   'SpecialDefense': 95.0,
#   'Speed': 110.0,
#   'Total': 525.0,
#   'Type': 'Psychic'},
#  197.0: {'Attack': 65.0,
#   'Defense': 110.0,
#   'HP': 95.0,
#   'Name': 'Umbreon',
#   'SpecialAttack': 60.0,
#   'SpecialDefense': 130.0,
#   'Speed': 65.0,
#   'Total': 525.0,
#   'Type': 'Dark'},
#  198.0: {'Attack': 85.0,
#   'Defense': 42.0,
#   'HP': 60.0,
#   'Name': 'Murkrow',
#   'SpecialAttack': 85.0,
#   'SpecialDefense': 42.0,
#   'Speed': 91.0,
#   'Total': 405.0,
#   'Type': 'DarkFlying'},
#  199.0: {'Attack': 75.0,
#   'Defense': 80.0,
#   'HP': 95.0,
#   'Name': 'Slowking',
#   'SpecialAttack': 100.0,
#   'SpecialDefense': 110.0,
#   'Speed': 30.0,
#   'Total': 490.0,
#   'Type': 'WaterPsychic'},
#  200.0: {'Attack': 60.0,
#   'Defense': 60.0,
#   'HP': 60.0,
#   'Name': 'Misdreavus',
#   'SpecialAttack': 85.0,
#   'SpecialDefense': 85.0,
#   'Speed': 85.0,
#   'Total': 435.0,
#   'Type': 'Ghost'},
#  201.0: {'Attack': 72.0,
#   'Defense': 48.0,
#   'HP': 48.0,
#   'Name': 'Unown',
#   'SpecialAttack': 72.0,
#   'SpecialDefense': 48.0,
#   'Speed': 48.0,
#   'Total': 336.0,
#   'Type': 'Psychic'},
#  202.0: {'Attack': 33.0,
#   'Defense': 58.0,
#   'HP': 190.0,
#   'Name': 'Wobbuffet',
#   'SpecialAttack': 33.0,
#   'SpecialDefense': 58.0,
#   'Speed': 33.0,
#   'Total': 405.0,
#   'Type': 'Psychic'},
#  203.0: {'Attack': 80.0,
#   'Defense': 65.0,
#   'HP': 70.0,
#   'Name': 'Girafarig',
#   'SpecialAttack': 90.0,
#   'SpecialDefense': 65.0,
#   'Speed': 85.0,
#   'Total': 455.0,
#   'Type': 'NormalPsychic'},
#  204.0: {'Attack': 65.0,
#   'Defense': 90.0,
#   'HP': 50.0,
#   'Name': 'Pineco',
#   'SpecialAttack': 35.0,
#   'SpecialDefense': 35.0,
#   'Speed': 15.0,
#   'Total': 290.0,
#   'Type': 'Bug'},
#  205.0: {'Attack': 90.0,
#   'Defense': 140.0,
#   'HP': 75.0,
#   'Name': 'Forretress',
#   'SpecialAttack': 60.0,
#   'SpecialDefense': 60.0,
#   'Speed': 40.0,
#   'Total': 465.0,
#   'Type': 'BugSteel'},
#  206.0: {'Attack': 70.0,
#   'Defense': 70.0,
#   'HP': 100.0,
#   'Name': 'Dunsparce',
#   'SpecialAttack': 65.0,
#   'SpecialDefense': 65.0,
#   'Speed': 45.0,
#   'Total': 415.0,
#   'Type': 'Normal'},
#  207.0: {'Attack': 75.0,
#   'Defense': 105.0,
#   'HP': 65.0,
#   'Name': 'Gligar',
#   'SpecialAttack': 35.0,
#   'SpecialDefense': 65.0,
#   'Speed': 85.0,
#   'Total': 430.0,
#   'Type': 'GroundFlying'},
#  208.0: {'Attack': 125.0,
#   'Defense': 230.0,
#   'HP': 75.0,
#   'Name': 'SteelixMega Steelix',
#   'SpecialAttack': 55.0,
#   'SpecialDefense': 95.0,
#   'Speed': 30.0,
#   'Total': 610.0,
#   'Type': 'SteelGround'},
#  209.0: {'Attack': 80.0,
#   'Defense': 50.0,
#   'HP': 60.0,
#   'Name': 'Snubbull',
#   'SpecialAttack': 40.0,
#   'SpecialDefense': 40.0,
#   'Speed': 30.0,
#   'Total': 300.0,
#   'Type': 'Fairy'},
#  210.0: {'Attack': 120.0,
#   'Defense': 75.0,
#   'HP': 90.0,
#   'Name': 'Granbull',
#   'SpecialAttack': 60.0,
#   'SpecialDefense': 60.0,
#   'Speed': 45.0,
#   'Total': 450.0,
#   'Type': 'Fairy'},
#  211.0: {'Attack': 95.0,
#   'Defense': 75.0,
#   'HP': 65.0,
#   'Name': 'Qwilfish',
#   'SpecialAttack': 55.0,
#   'SpecialDefense': 55.0,
#   'Speed': 85.0,
#   'Total': 430.0,
#   'Type': 'WaterPoison'},
#  212.0: {'Attack': 150.0,
#   'Defense': 140.0,
#   'HP': 70.0,
#   'Name': 'ScizorMega Scizor',
#   'SpecialAttack': 65.0,
#   'SpecialDefense': 100.0,
#   'Speed': 75.0,
#   'Total': 600.0,
#   'Type': 'BugSteel'},
#  213.0: {'Attack': 10.0,
#   'Defense': 230.0,
#   'HP': 20.0,
#   'Name': 'Shuckle',
#   'SpecialAttack': 10.0,
#   'SpecialDefense': 230.0,
#   'Speed': 5.0,
#   'Total': 505.0,
#   'Type': 'BugRock'},
#  214.0: {'Attack': 185.0,
#   'Defense': 115.0,
#   'HP': 80.0,
#   'Name': 'HeracrossMega Heracross',
#   'SpecialAttack': 40.0,
#   'SpecialDefense': 105.0,
#   'Speed': 75.0,
#   'Total': 600.0,
#   'Type': 'BugFighting'},
#  215.0: {'Attack': 95.0,
#   'Defense': 55.0,
#   'HP': 55.0,
#   'Name': 'Sneasel',
#   'SpecialAttack': 35.0,
#   'SpecialDefense': 75.0,
#   'Speed': 115.0,
#   'Total': 430.0,
#   'Type': 'DarkIce'},
#  216.0: {'Attack': 80.0,
#   'Defense': 50.0,
#   'HP': 60.0,
#   'Name': 'Teddiursa',
#   'SpecialAttack': 50.0,
#   'SpecialDefense': 50.0,
#   'Speed': 40.0,
#   'Total': 330.0,
#   'Type': 'Normal'},
#  217.0: {'Attack': 130.0,
#   'Defense': 75.0,
#   'HP': 90.0,
#   'Name': 'Ursaring',
#   'SpecialAttack': 75.0,
#   'SpecialDefense': 75.0,
#   'Speed': 55.0,
#   'Total': 500.0,
#   'Type': 'Normal'},
#  218.0: {'Attack': 40.0,
#   'Defense': 40.0,
#   'HP': 40.0,
#   'Name': 'Slugma',
#   'SpecialAttack': 70.0,
#   'SpecialDefense': 40.0,
#   'Speed': 20.0,
#   'Total': 250.0,
#   'Type': 'Fire'},
#  219.0: {'Attack': 50.0,
#   'Defense': 120.0,
#   'HP': 50.0,
#   'Name': 'Magcargo',
#   'SpecialAttack': 80.0,
#   'SpecialDefense': 80.0,
#   'Speed': 30.0,
#   'Total': 410.0,
#   'Type': 'FireRock'},
#  220.0: {'Attack': 50.0,
#   'Defense': 40.0,
#   'HP': 50.0,
#   'Name': 'Swinub',
#   'SpecialAttack': 30.0,
#   'SpecialDefense': 30.0,
#   'Speed': 50.0,
#   'Total': 250.0,
#   'Type': 'IceGround'},
#  221.0: {'Attack': 100.0,
#   'Defense': 80.0,
#   'HP': 100.0,
#   'Name': 'Piloswine',
#   'SpecialAttack': 60.0,
#   'SpecialDefense': 60.0,
#   'Speed': 50.0,
#   'Total': 450.0,
#   'Type': 'IceGround'},
#  222.0: {'Attack': 55.0,
#   'Defense': 85.0,
#   'HP': 55.0,
#   'Name': 'Corsola',
#   'SpecialAttack': 65.0,
#   'SpecialDefense': 85.0,
#   'Speed': 35.0,
#   'Total': 380.0,
#   'Type': 'WaterRock'},
#  223.0: {'Attack': 65.0,
#   'Defense': 35.0,
#   'HP': 35.0,
#   'Name': 'Remoraid',
#   'SpecialAttack': 65.0,
#   'SpecialDefense': 35.0,
#   'Speed': 65.0,
#   'Total': 300.0,
#   'Type': 'Water'},
#  224.0: {'Attack': 105.0,
#   'Defense': 75.0,
#   'HP': 75.0,
#   'Name': 'Octillery',
#   'SpecialAttack': 105.0,
#   'SpecialDefense': 75.0,
#   'Speed': 45.0,
#   'Total': 480.0,
#   'Type': 'Water'},
#  225.0: {'Attack': 55.0,
#   'Defense': 45.0,
#   'HP': 45.0,
#   'Name': 'Delibird',
#   'SpecialAttack': 65.0,
#   'SpecialDefense': 45.0,
#   'Speed': 75.0,
#   'Total': 330.0,
#   'Type': 'IceFlying'},
#  226.0: {'Attack': 40.0,
#   'Defense': 70.0,
#   'HP': 65.0,
#   'Name': 'Mantine',
#   'SpecialAttack': 80.0,
#   'SpecialDefense': 140.0,
#   'Speed': 70.0,
#   'Total': 465.0,
#   'Type': 'WaterFlying'},
#  227.0: {'Attack': 80.0,
#   'Defense': 140.0,
#   'HP': 65.0,
#   'Name': 'Skarmory',
#   'SpecialAttack': 40.0,
#   'SpecialDefense': 70.0,
#   'Speed': 70.0,
#   'Total': 465.0,
#   'Type': 'SteelFlying'},
#  228.0: {'Attack': 60.0,
#   'Defense': 30.0,
#   'HP': 45.0,
#   'Name': 'Houndour',
#   'SpecialAttack': 80.0,
#   'SpecialDefense': 50.0,
#   'Speed': 65.0,
#   'Total': 330.0,
#   'Type': 'DarkFire'},
#  229.0: {'Attack': 90.0,
#   'Defense': 90.0,
#   'HP': 75.0,
#   'Name': 'HoundoomMega Houndoom',
#   'SpecialAttack': 140.0,
#   'SpecialDefense': 90.0,
#   'Speed': 115.0,
#   'Total': 600.0,
#   'Type': 'DarkFire'},
#  230.0: {'Attack': 95.0,
#   'Defense': 95.0,
#   'HP': 75.0,
#   'Name': 'Kingdra',
#   'SpecialAttack': 95.0,
#   'SpecialDefense': 95.0,
#   'Speed': 85.0,
#   'Total': 540.0,
#   'Type': 'WaterDragon'},
#  231.0: {'Attack': 60.0,
#   'Defense': 60.0,
#   'HP': 90.0,
#   'Name': 'Phanpy',
#   'SpecialAttack': 40.0,
#   'SpecialDefense': 40.0,
#   'Speed': 40.0,
#   'Total': 330.0,
#   'Type': 'Ground'},
#  232.0: {'Attack': 120.0,
#   'Defense': 120.0,
#   'HP': 90.0,
#   'Name': 'Donphan',
#   'SpecialAttack': 60.0,
#   'SpecialDefense': 60.0,
#   'Speed': 50.0,
#   'Total': 500.0,
#   'Type': 'Ground'},
#  233.0: {'Attack': 80.0,
#   'Defense': 90.0,
#   'HP': 85.0,
#   'Name': 'Porygon2',
#   'SpecialAttack': 105.0,
#   'SpecialDefense': 95.0,
#   'Speed': 60.0,
#   'Total': 515.0,
#   'Type': 'Normal'},
#  234.0: {'Attack': 95.0,
#   'Defense': 62.0,
#   'HP': 73.0,
#   'Name': 'Stantler',
#   'SpecialAttack': 85.0,
#   'SpecialDefense': 65.0,
#   'Speed': 85.0,
#   'Total': 465.0,
#   'Type': 'Normal'},
#  235.0: {'Attack': 20.0,
#   'Defense': 35.0,
#   'HP': 55.0,
#   'Name': 'Smeargle',
#   'SpecialAttack': 20.0,
#   'SpecialDefense': 45.0,
#   'Speed': 75.0,
#   'Total': 250.0,
#   'Type': 'Normal'},
#  236.0: {'Attack': 35.0,
#   'Defense': 35.0,
#   'HP': 35.0,
#   'Name': 'Tyrogue',
#   'SpecialAttack': 35.0,
#   'SpecialDefense': 35.0,
#   'Speed': 35.0,
#   'Total': 210.0,
#   'Type': 'Fighting'},
#  237.0: {'Attack': 95.0,
#   'Defense': 95.0,
#   'HP': 50.0,
#   'Name': 'Hitmontop',
#   'SpecialAttack': 35.0,
#   'SpecialDefense': 110.0,
#   'Speed': 70.0,
#   'Total': 455.0,
#   'Type': 'Fighting'},
#  238.0: {'Attack': 30.0,
#   'Defense': 15.0,
#   'HP': 45.0,
#   'Name': 'Smoochum',
#   'SpecialAttack': 85.0,
#   'SpecialDefense': 65.0,
#   'Speed': 65.0,
#   'Total': 305.0,
#   'Type': 'IcePsychic'},
#  239.0: {'Attack': 63.0,
#   'Defense': 37.0,
#   'HP': 45.0,
#   'Name': 'Elekid',
#   'SpecialAttack': 65.0,
#   'SpecialDefense': 55.0,
#   'Speed': 95.0,
#   'Total': 360.0,
#   'Type': 'Electric'},
#  240.0: {'Attack': 75.0,
#   'Defense': 37.0,
#   'HP': 45.0,
#   'Name': 'Magby',
#   'SpecialAttack': 70.0,
#   'SpecialDefense': 55.0,
#   'Speed': 83.0,
#   'Total': 365.0,
#   'Type': 'Fire'},
#  241.0: {'Attack': 80.0,
#   'Defense': 105.0,
#   'HP': 95.0,
#   'Name': 'Miltank',
#   'SpecialAttack': 40.0,
#   'SpecialDefense': 70.0,
#   'Speed': 100.0,
#   'Total': 490.0,
#   'Type': 'Normal'},
#  242.0: {'Attack': 10.0,
#   'Defense': 10.0,
#   'HP': 255.0,
#   'Name': 'Blissey',
#   'SpecialAttack': 75.0,
#   'SpecialDefense': 135.0,
#   'Speed': 55.0,
#   'Total': 540.0,
#   'Type': 'Normal'},
#  243.0: {'Attack': 85.0,
#   'Defense': 75.0,
#   'HP': 90.0,
#   'Name': 'Raikou',
#   'SpecialAttack': 115.0,
#   'SpecialDefense': 100.0,
#   'Speed': 115.0,
#   'Total': 580.0,
#   'Type': 'Electric'},
#  244.0: {'Attack': 115.0,
#   'Defense': 85.0,
#   'HP': 115.0,
#   'Name': 'Entei',
#   'SpecialAttack': 90.0,
#   'SpecialDefense': 75.0,
#   'Speed': 100.0,
#   'Total': 580.0,
#   'Type': 'Fire'},
#  245.0: {'Attack': 75.0,
#   'Defense': 115.0,
#   'HP': 100.0,
#   'Name': 'Suicune',
#   'SpecialAttack': 90.0,
#   'SpecialDefense': 115.0,
#   'Speed': 85.0,
#   'Total': 580.0,
#   'Type': 'Water'},
#  246.0: {'Attack': 64.0,
#   'Defense': 50.0,
#   'HP': 50.0,
#   'Name': 'Larvitar',
#   'SpecialAttack': 45.0,
#   'SpecialDefense': 50.0,
#   'Speed': 41.0,
#   'Total': 300.0,
#   'Type': 'RockGround'},
#  247.0: {'Attack': 84.0,
#   'Defense': 70.0,
#   'HP': 70.0,
#   'Name': 'Pupitar',
#   'SpecialAttack': 65.0,
#   'SpecialDefense': 70.0,
#   'Speed': 51.0,
#   'Total': 410.0,
#   'Type': 'RockGround'},
#  248.0: {'Attack': 164.0,
#   'Defense': 150.0,
#   'HP': 100.0,
#   'Name': 'TyranitarMega Tyranitar',
#   'SpecialAttack': 95.0,
#   'SpecialDefense': 120.0,
#   'Speed': 71.0,
#   'Total': 700.0,
#   'Type': 'RockDark'},
#  249.0: {'Attack': 90.0,
#   'Defense': 130.0,
#   'HP': 106.0,
#   'Name': 'Lugia',
#   'SpecialAttack': 90.0,
#   'SpecialDefense': 154.0,
#   'Speed': 110.0,
#   'Total': 680.0,
#   'Type': 'PsychicFlying'},
#  250.0: {'Attack': 130.0,
#   'Defense': 90.0,
#   'HP': 106.0,
#   'Name': 'Ho-oh',
#   'SpecialAttack': 110.0,
#   'SpecialDefense': 154.0,
#   'Speed': 90.0,
#   'Total': 680.0,
#   'Type': 'FireFlying'},
#  251.0: {'Attack': 100.0,
#   'Defense': 100.0,
#   'HP': 100.0,
#   'Name': 'Celebi',
#   'SpecialAttack': 100.0,
#   'SpecialDefense': 100.0,
#   'Speed': 100.0,
#   'Total': 600.0,
#   'Type': 'PsychicGrass'},
#  252.0: {'Attack': 45.0,
#   'Defense': 35.0,
#   'HP': 40.0,
#   'Name': 'Treecko',
#   'SpecialAttack': 65.0,
#   'SpecialDefense': 55.0,
#   'Speed': 70.0,
#   'Total': 310.0,
#   'Type': 'Grass'},
#  253.0: {'Attack': 65.0,
#   'Defense': 45.0,
#   'HP': 50.0,
#   'Name': 'Grovyle',
#   'SpecialAttack': 85.0,
#   'SpecialDefense': 65.0,
#   'Speed': 95.0,
# ...
#  639.0: {'Attack': 129.0,
#   'Defense': 90.0,
#   'HP': 91.0,
#   'Name': 'Terrakion',
#   'SpecialAttack': 72.0,
#   'SpecialDefense': 90.0,
#   'Speed': 108.0,
#   'Total': 580.0,
#   'Type': 'RockFighting'},
#  640.0: {'Attack': 90.0,
#   'Defense': 72.0,
#   'HP': 91.0,
#   'Name': 'Virizion',
#   'SpecialAttack': 90.0,
#   'SpecialDefense': 129.0,
#   'Speed': 108.0,
#   'Total': 580.0,
#   'Type': 'GrassFighting'},
#  641.0: {'Attack': 100.0,
#   'Defense': 80.0,
#   'HP': 79.0,
#   'Name': 'TornadusTherian Forme',
#   'SpecialAttack': 110.0,
#   'SpecialDefense': 90.0,
#   'Speed': 121.0,
#   'Total': 580.0,
#   'Type': 'Flying'},
#  642.0: {'Attack': 105.0,
#   'Defense': 70.0,
#   'HP': 79.0,
#   'Name': 'ThundurusTherian Forme',
#   'SpecialAttack': 145.0,
#   'SpecialDefense': 80.0,
#   'Speed': 101.0,
#   'Total': 580.0,
#   'Type': 'ElectricFlying'},
#  643.0: {'Attack': 120.0,
#   'Defense': 100.0,
#   'HP': 100.0,
#   'Name': 'Reshiram',
#   'SpecialAttack': 150.0,
#   'SpecialDefense': 120.0,
#   'Speed': 90.0,
#   'Total': 680.0,
#   'Type': 'DragonFire'},
#  644.0: {'Attack': 150.0,
#   'Defense': 120.0,
#   'HP': 100.0,
#   'Name': 'Zekrom',
#   'SpecialAttack': 120.0,
#   'SpecialDefense': 100.0,
#   'Speed': 90.0,
#   'Total': 680.0,
#   'Type': 'DragonElectric'},
#  645.0: {'Attack': 145.0,
#   'Defense': 90.0,
#   'HP': 89.0,
#   'Name': 'LandorusTherian Forme',
#   'SpecialAttack': 105.0,
#   'SpecialDefense': 80.0,
#   'Speed': 91.0,
#   'Total': 600.0,
#   'Type': 'GroundFlying'},
#  646.0: {'Attack': 120.0,
#   'Defense': 90.0,
#   'HP': 125.0,
#   'Name': 'KyuremWhite Kyurem',
#   'SpecialAttack': 170.0,
#   'SpecialDefense': 100.0,
#   'Speed': 95.0,
#   'Total': 700.0,
#   'Type': 'DragonIce'},
#  647.0: {'Attack': 72.0,
#   'Defense': 90.0,
#   'HP': 91.0,
#   'Name': 'KeldeoResolute Forme',
#   'SpecialAttack': 129.0,
#   'SpecialDefense': 90.0,
#   'Speed': 108.0,
#   'Total': 580.0,
#   'Type': 'WaterFighting'},
#  648.0: {'Attack': 128.0,
#   'Defense': 90.0,
#   'HP': 100.0,
#   'Name': 'MeloettaPirouette Forme',
#   'SpecialAttack': 77.0,
#   'SpecialDefense': 77.0,
#   'Speed': 128.0,
#   'Total': 600.0,
#   'Type': 'NormalFighting'},
#  649.0: {'Attack': 120.0,
#   'Defense': 95.0,
#   'HP': 71.0,
#   'Name': 'Genesect',
#   'SpecialAttack': 120.0,
#   'SpecialDefense': 95.0,
#   'Speed': 99.0,
#   'Total': 600.0,
#   'Type': 'BugSteel'},
#  650.0: {'Attack': 61.0,
#   'Defense': 65.0,
#   'HP': 56.0,
#   'Name': 'Chespin',
#   'SpecialAttack': 48.0,
#   'SpecialDefense': 45.0,
#   'Speed': 38.0,
#   'Total': 313.0,
#   'Type': 'Grass'},
#  651.0: {'Attack': 78.0,
#   'Defense': 95.0,
#   'HP': 61.0,
#   'Name': 'Quilladin',
#   'SpecialAttack': 56.0,
#   'SpecialDefense': 58.0,
#   'Speed': 57.0,
#   'Total': 405.0,
#   'Type': 'Grass'},
#  652.0: {'Attack': 107.0,
#   'Defense': 122.0,
#   'HP': 88.0,
#   'Name': 'Chesnaught',
#   'SpecialAttack': 74.0,
#   'SpecialDefense': 75.0,
#   'Speed': 64.0,
#   'Total': 530.0,
#   'Type': 'GrassFighting'},
#  653.0: {'Attack': 45.0,
#   'Defense': 40.0,
#   'HP': 40.0,
#   'Name': 'Fennekin',
#   'SpecialAttack': 62.0,
#   'SpecialDefense': 60.0,
#   'Speed': 60.0,
#   'Total': 307.0,
#   'Type': 'Fire'},
#  654.0: {'Attack': 59.0,
#   'Defense': 58.0,
#   'HP': 59.0,
#   'Name': 'Braixen',
#   'SpecialAttack': 90.0,
#   'SpecialDefense': 70.0,
#   'Speed': 73.0,
#   'Total': 409.0,
#   'Type': 'Fire'},
#  655.0: {'Attack': 69.0,
#   'Defense': 72.0,
#   'HP': 75.0,
#   'Name': 'Delphox',
#   'SpecialAttack': 114.0,
#   'SpecialDefense': 100.0,
#   'Speed': 104.0,
#   'Total': 534.0,
#   'Type': 'FirePsychic'},
#  656.0: {'Attack': 56.0,
#   'Defense': 40.0,
#   'HP': 41.0,
#   'Name': 'Froakie',
#   'SpecialAttack': 62.0,
#   'SpecialDefense': 44.0,
#   'Speed': 71.0,
#   'Total': 314.0,
#   'Type': 'Water'},
#  657.0: {'Attack': 63.0,
#   'Defense': 52.0,
#   'HP': 54.0,
#   'Name': 'Frogadier',
#   'SpecialAttack': 83.0,
#   'SpecialDefense': 56.0,
#   'Speed': 97.0,
#   'Total': 405.0,
#   'Type': 'Water'},
#  658.0: {'Attack': 95.0,
#   'Defense': 67.0,
#   'HP': 72.0,
#   'Name': 'Greninja',
#   'SpecialAttack': 103.0,
#   'SpecialDefense': 71.0,
#   'Speed': 122.0,
#   'Total': 530.0,
#   'Type': 'WaterDark'},
#  659.0: {'Attack': 36.0,
#   'Defense': 38.0,
#   'HP': 38.0,
#   'Name': 'Bunnelby',
#   'SpecialAttack': 32.0,
#   'SpecialDefense': 36.0,
#   'Speed': 57.0,
#   'Total': 237.0,
#   'Type': 'Normal'},
#  660.0: {'Attack': 56.0,
#   'Defense': 77.0,
#   'HP': 85.0,
#   'Name': 'Diggersby',
#   'SpecialAttack': 50.0,
#   'SpecialDefense': 77.0,
#   'Speed': 78.0,
#   'Total': 423.0,
#   'Type': 'NormalGround'},
#  661.0: {'Attack': 50.0,
#   'Defense': 43.0,
#   'HP': 45.0,
#   'Name': 'Fletchling',
#   'SpecialAttack': 40.0,
#   'SpecialDefense': 38.0,
#   'Speed': 62.0,
#   'Total': 278.0,
#   'Type': 'NormalFlying'},
#  662.0: {'Attack': 73.0,
#   'Defense': 55.0,
#   'HP': 62.0,
#   'Name': 'Fletchinder',
#   'SpecialAttack': 56.0,
#   'SpecialDefense': 52.0,
#   'Speed': 84.0,
#   'Total': 382.0,
#   'Type': 'FireFlying'},
#  663.0: {'Attack': 81.0,
#   'Defense': 71.0,
#   'HP': 78.0,
#   'Name': 'Talonflame',
#   'SpecialAttack': 74.0,
#   'SpecialDefense': 69.0,
#   'Speed': 126.0,
#   'Total': 499.0,
#   'Type': 'FireFlying'},
#  664.0: {'Attack': 35.0,
#   'Defense': 40.0,
#   'HP': 38.0,
#   'Name': 'Scatterbug',
#   'SpecialAttack': 27.0,
#   'SpecialDefense': 25.0,
#   'Speed': 35.0,
#   'Total': 200.0,
#   'Type': 'Bug'},
#  665.0: {'Attack': 22.0,
#   'Defense': 60.0,
#   'HP': 45.0,
#   'Name': 'Spewpa',
#   'SpecialAttack': 27.0,
#   'SpecialDefense': 30.0,
#   'Speed': 29.0,
#   'Total': 213.0,
#   'Type': 'Bug'},
#  666.0: {'Attack': 52.0,
#   'Defense': 50.0,
#   'HP': 80.0,
#   'Name': 'Vivillon',
#   'SpecialAttack': 90.0,
#   'SpecialDefense': 50.0,
#   'Speed': 89.0,
#   'Total': 411.0,
#   'Type': 'BugFlying'},
#  667.0: {'Attack': 50.0,
#   'Defense': 58.0,
#   'HP': 62.0,
#   'Name': 'Litleo',
#   'SpecialAttack': 73.0,
#   'SpecialDefense': 54.0,
#   'Speed': 72.0,
#   'Total': 369.0,
#   'Type': 'FireNormal'},
#  668.0: {'Attack': 68.0,
#   'Defense': 72.0,
#   'HP': 86.0,
#   'Name': 'Pyroar',
#   'SpecialAttack': 109.0,
#   'SpecialDefense': 66.0,
#   'Speed': 106.0,
#   'Total': 507.0,
#   'Type': 'FireNormal'},
#  669.0: {'Attack': 38.0,
#   'Defense': 39.0,
#   'HP': 44.0,
#   'Name': 'Flab\xc3\xa9b\xc3\xa9',
#   'SpecialAttack': 61.0,
#   'SpecialDefense': 79.0,
#   'Speed': 42.0,
#   'Total': 303.0,
#   'Type': 'Fairy'},
#  670.0: {'Attack': 45.0,
#   'Defense': 47.0,
#   'HP': 54.0,
#   'Name': 'Floette',
#   'SpecialAttack': 75.0,
#   'SpecialDefense': 98.0,
#   'Speed': 52.0,
#   'Total': 371.0,
#   'Type': 'Fairy'},
#  671.0: {'Attack': 65.0,
#   'Defense': 68.0,
#   'HP': 78.0,
#   'Name': 'Florges',
#   'SpecialAttack': 112.0,
#   'SpecialDefense': 154.0,
#   'Speed': 75.0,
#   'Total': 552.0,
#   'Type': 'Fairy'},
#  672.0: {'Attack': 65.0,
#   'Defense': 48.0,
#   'HP': 66.0,
#   'Name': 'Skiddo',
#   'SpecialAttack': 62.0,
#   'SpecialDefense': 57.0,
#   'Speed': 52.0,
#   'Total': 350.0,
#   'Type': 'Grass'},
#  673.0: {'Attack': 100.0,
#   'Defense': 62.0,
#   'HP': 123.0,
#   'Name': 'Gogoat',
#   'SpecialAttack': 97.0,
#   'SpecialDefense': 81.0,
#   'Speed': 68.0,
#   'Total': 531.0,
#   'Type': 'Grass'},
#  674.0: {'Attack': 82.0,
#   'Defense': 62.0,
#   'HP': 67.0,
#   'Name': 'Pancham',
#   'SpecialAttack': 46.0,
#   'SpecialDefense': 48.0,
#   'Speed': 43.0,
#   'Total': 348.0,
#   'Type': 'Fighting'},
#  675.0: {'Attack': 124.0,
#   'Defense': 78.0,
#   'HP': 95.0,
#   'Name': 'Pangoro',
#   'SpecialAttack': 69.0,
#   'SpecialDefense': 71.0,
#   'Speed': 58.0,
#   'Total': 495.0,
#   'Type': 'FightingDark'},
#  676.0: {'Attack': 80.0,
#   'Defense': 60.0,
#   'HP': 75.0,
#   'Name': 'Furfrou',
#   'SpecialAttack': 65.0,
#   'SpecialDefense': 90.0,
#   'Speed': 102.0,
#   'Total': 472.0,
#   'Type': 'Normal'},
#  677.0: {'Attack': 48.0,
#   'Defense': 54.0,
#   'HP': 62.0,
#   'Name': 'Espurr',
#   'SpecialAttack': 63.0,
#   'SpecialDefense': 60.0,
#   'Speed': 68.0,
#   'Total': 355.0,
#   'Type': 'Psychic'},
#  678.0: {'Attack': 48.0,
#   'Defense': 76.0,
#   'HP': 74.0,
#   'Name': 'MeowsticFemale',
#   'SpecialAttack': 83.0,
#   'SpecialDefense': 81.0,
#   'Speed': 104.0,
#   'Total': 466.0,
#   'Type': 'Psychic'},
#  679.0: {'Attack': 80.0,
#   'Defense': 100.0,
#   'HP': 45.0,
#   'Name': 'Honedge',
#   'SpecialAttack': 35.0,
#   'SpecialDefense': 37.0,
#   'Speed': 28.0,
#   'Total': 325.0,
#   'Type': 'SteelGhost'},
#  680.0: {'Attack': 110.0,
#   'Defense': 150.0,
#   'HP': 59.0,
#   'Name': 'Doublade',
#   'SpecialAttack': 45.0,
#   'SpecialDefense': 49.0,
#   'Speed': 35.0,
#   'Total': 448.0,
#   'Type': 'SteelGhost'},
#  681.0: {'Attack': 50.0,
#   'Defense': 150.0,
#   'HP': 60.0,
#   'Name': 'AegislashShield Forme',
#   'SpecialAttack': 50.0,
#   'SpecialDefense': 150.0,
#   'Speed': 60.0,
#   'Total': 520.0,
#   'Type': 'SteelGhost'},
#  682.0: {'Attack': 52.0,
#   'Defense': 60.0,
#   'HP': 78.0,
#   'Name': 'Spritzee',
#   'SpecialAttack': 63.0,
#   'SpecialDefense': 65.0,
#   'Speed': 23.0,
#   'Total': 341.0,
#   'Type': 'Fairy'},
#  683.0: {'Attack': 72.0,
#   'Defense': 72.0,
#   'HP': 101.0,
#   'Name': 'Aromatisse',
#   'SpecialAttack': 99.0,
#   'SpecialDefense': 89.0,
#   'Speed': 29.0,
#   'Total': 462.0,
#   'Type': 'Fairy'},
#  684.0: {'Attack': 48.0,
#   'Defense': 66.0,
#   'HP': 62.0,
#   'Name': 'Swirlix',
#   'SpecialAttack': 59.0,
#   'SpecialDefense': 57.0,
#   'Speed': 49.0,
#   'Total': 341.0,
#   'Type': 'Fairy'},
#  685.0: {'Attack': 80.0,
#   'Defense': 86.0,
#   'HP': 82.0,
#   'Name': 'Slurpuff',
#   'SpecialAttack': 85.0,
#   'SpecialDefense': 75.0,
#   'Speed': 72.0,
#   'Total': 480.0,
#   'Type': 'Fairy'},
#  686.0: {'Attack': 54.0,
#   'Defense': 53.0,
#   'HP': 53.0,
#   'Name': 'Inkay',
#   'SpecialAttack': 37.0,
#   'SpecialDefense': 46.0,
#   'Speed': 45.0,
#   'Total': 288.0,
#   'Type': 'DarkPsychic'},
#  687.0: {'Attack': 92.0,
#   'Defense': 88.0,
#   'HP': 86.0,
#   'Name': 'Malamar',
#   'SpecialAttack': 68.0,
#   'SpecialDefense': 75.0,
#   'Speed': 73.0,
#   'Total': 482.0,
#   'Type': 'DarkPsychic'},
#  688.0: {'Attack': 52.0,
#   'Defense': 67.0,
#   'HP': 42.0,
#   'Name': 'Binacle',
#   'SpecialAttack': 39.0,
#   'SpecialDefense': 56.0,
#   'Speed': 50.0,
#   'Total': 306.0,
#   'Type': 'RockWater'},
#  689.0: {'Attack': 105.0,
#   'Defense': 115.0,
#   'HP': 72.0,
#   'Name': 'Barbaracle',
#   'SpecialAttack': 54.0,
#   'SpecialDefense': 86.0,
#   'Speed': 68.0,
#   'Total': 500.0,
#   'Type': 'RockWater'},
#  690.0: {'Attack': 60.0,
#   'Defense': 60.0,
#   'HP': 50.0,
#   'Name': 'Skrelp',
#   'SpecialAttack': 60.0,
#   'SpecialDefense': 60.0,
#   'Speed': 30.0,
#   'Total': 320.0,
#   'Type': 'PoisonWater'},
#  691.0: {'Attack': 75.0,
#   'Defense': 90.0,
#   'HP': 65.0,
#   'Name': 'Dragalge',
#   'SpecialAttack': 97.0,
#   'SpecialDefense': 123.0,
#   'Speed': 44.0,
#   'Total': 494.0,
#   'Type': 'PoisonDragon'},
#  692.0: {'Attack': 53.0,
#   'Defense': 62.0,
#   'HP': 50.0,
#   'Name': 'Clauncher',
#   'SpecialAttack': 58.0,
#   'SpecialDefense': 63.0,
#   'Speed': 44.0,
#   'Total': 330.0,
#   'Type': 'Water'},
#  693.0: {'Attack': 73.0,
#   'Defense': 88.0,
#   'HP': 71.0,
#   'Name': 'Clawitzer',
#   'SpecialAttack': 120.0,
#   'SpecialDefense': 89.0,
#   'Speed': 59.0,
#   'Total': 500.0,
#   'Type': 'Water'},
#  694.0: {'Attack': 38.0,
#   'Defense': 33.0,
#   'HP': 44.0,
#   'Name': 'Helioptile',
#   'SpecialAttack': 61.0,
#   'SpecialDefense': 43.0,
#   'Speed': 70.0,
#   'Total': 289.0,
#   'Type': 'ElectricNormal'},
#  695.0: {'Attack': 55.0,
#   'Defense': 52.0,
#   'HP': 62.0,
#   'Name': 'Heliolisk',
#   'SpecialAttack': 109.0,
#   'SpecialDefense': 94.0,
#   'Speed': 109.0,
#   'Total': 481.0,
#   'Type': 'ElectricNormal'},
#  696.0: {'Attack': 89.0,
#   'Defense': 77.0,
#   'HP': 58.0,
#   'Name': 'Tyrunt',
#   'SpecialAttack': 45.0,
#   'SpecialDefense': 45.0,
#   'Speed': 48.0,
#   'Total': 362.0,
#   'Type': 'RockDragon'},
#  697.0: {'Attack': 121.0,
#   'Defense': 119.0,
#   'HP': 82.0,
#   'Name': 'Tyrantrum',
#   'SpecialAttack': 69.0,
#   'SpecialDefense': 59.0,
#   'Speed': 71.0,
#   'Total': 521.0,
#   'Type': 'RockDragon'},
#  698.0: {'Attack': 59.0,
#   'Defense': 50.0,
#   'HP': 77.0,
#   'Name': 'Amaura',
#   'SpecialAttack': 67.0,
#   'SpecialDefense': 63.0,
#   'Speed': 46.0,
#   'Total': 362.0,
#   'Type': 'RockIce'},
#  699.0: {'Attack': 77.0,
#   'Defense': 72.0,
#   'HP': 123.0,
#   'Name': 'Aurorus',
#   'SpecialAttack': 99.0,
#   'SpecialDefense': 92.0,
#   'Speed': 58.0,
#   'Total': 521.0,
#   'Type': 'RockIce'},
#  700.0: {'Attack': 65.0,
#   'Defense': 65.0,
#   'HP': 95.0,
#   'Name': 'Sylveon',
#   'SpecialAttack': 110.0,
#   'SpecialDefense': 130.0,
#   'Speed': 60.0,
#   'Total': 525.0,
#   'Type': 'Fairy'},
#  701.0: {'Attack': 92.0,
#   'Defense': 75.0,
#   'HP': 78.0,
#   'Name': 'Hawlucha',
#   'SpecialAttack': 74.0,
#   'SpecialDefense': 63.0,
#   'Speed': 118.0,
#   'Total': 500.0,
#   'Type': 'FightingFlying'},
#  702.0: {'Attack': 58.0,
#   'Defense': 57.0,
#   'HP': 67.0,
#   'Name': 'Dedenne',
#   'SpecialAttack': 81.0,
#   'SpecialDefense': 67.0,
#   'Speed': 101.0,
#   'Total': 431.0,
#   'Type': 'ElectricFairy'},
#  703.0: {'Attack': 50.0,
#   'Defense': 150.0,
#   'HP': 50.0,
#   'Name': 'Carbink',
#   'SpecialAttack': 50.0,
#   'SpecialDefense': 150.0,
#   'Speed': 50.0,
#   'Total': 500.0,
#   'Type': 'RockFairy'},
#  704.0: {'Attack': 50.0,
#   'Defense': 35.0,
#   'HP': 45.0,
#   'Name': 'Goomy',
#   'SpecialAttack': 55.0,
#   'SpecialDefense': 75.0,
#   'Speed': 40.0,
#   'Total': 300.0,
#   'Type': 'Dragon'},
#  705.0: {'Attack': 75.0,
#   'Defense': 53.0,
#   'HP': 68.0,
#   'Name': 'Sliggoo',
#   'SpecialAttack': 83.0,
#   'SpecialDefense': 113.0,
#   'Speed': 60.0,
#   'Total': 452.0,
#   'Type': 'Dragon'},
#  706.0: {'Attack': 100.0,
#   'Defense': 70.0,
#   'HP': 90.0,
#   'Name': 'Goodra',
#   'SpecialAttack': 110.0,
#   'SpecialDefense': 150.0,
#   'Speed': 80.0,
#   'Total': 600.0,
#   'Type': 'Dragon'},
#  707.0: {'Attack': 80.0,
#   'Defense': 91.0,
#   'HP': 57.0,
#   'Name': 'Klefki',
#   'SpecialAttack': 80.0,
#   'SpecialDefense': 87.0,
#   'Speed': 75.0,
#   'Total': 470.0,
#   'Type': 'SteelFairy'},
#  708.0: {'Attack': 70.0,
#   'Defense': 48.0,
#   'HP': 43.0,
#   'Name': 'Phantump',
#   'SpecialAttack': 50.0,
#   'SpecialDefense': 60.0,
#   'Speed': 38.0,
#   'Total': 309.0,
#   'Type': 'GhostGrass'},
#  709.0: {'Attack': 110.0,
#   'Defense': 76.0,
#   'HP': 85.0,
#   'Name': 'Trevenant',
#   'SpecialAttack': 65.0,
#   'SpecialDefense': 82.0,
#   'Speed': 56.0,
#   'Total': 474.0,
#   'Type': 'GhostGrass'},
#  710.0: {'Attack': 66.0,
#   'Defense': 70.0,
#   'HP': 59.0,
#   'Name': 'PumpkabooSuper Size',
#   'SpecialAttack': 44.0,
#   'SpecialDefense': 55.0,
#   'Speed': 41.0,
#   'Total': 335.0,
#   'Type': 'GhostGrass'},
#  711.0: {'Attack': 100.0,
#   'Defense': 122.0,
#   'HP': 85.0,
#   'Name': 'GourgeistSuper Size',
#   'SpecialAttack': 58.0,
#   'SpecialDefense': 75.0,
#   'Speed': 54.0,
#   'Total': 494.0,
#   'Type': 'GhostGrass'},
#  712.0: {'Attack': 69.0,
#   'Defense': 85.0,
#   'HP': 55.0,
#   'Name': 'Bergmite',
#   'SpecialAttack': 32.0,
#   'SpecialDefense': 35.0,
#   'Speed': 28.0,
#   'Total': 304.0,
#   'Type': 'Ice'},
#  713.0: {'Attack': 117.0,
#   'Defense': 184.0,
#   'HP': 95.0,
#   'Name': 'Avalugg',
#   'SpecialAttack': 44.0,
#   'SpecialDefense': 46.0,
#   'Speed': 28.0,
#   'Total': 514.0,
#   'Type': 'Ice'},
#  714.0: {'Attack': 30.0,
#   'Defense': 35.0,
#   'HP': 40.0,
#   'Name': 'Noibat',
#   'SpecialAttack': 45.0,
#   'SpecialDefense': 40.0,
#   'Speed': 55.0,
#   'Total': 245.0,
#   'Type': 'FlyingDragon'},
#  715.0: {'Attack': 70.0,
#   'Defense': 80.0,
#   'HP': 85.0,
#   'Name': 'Noivern',
#   'SpecialAttack': 97.0,
#   'SpecialDefense': 80.0,
#   'Speed': 123.0,
#   'Total': 535.0,
#   'Type': 'FlyingDragon'},
#  716.0: {'Attack': 131.0,
#   'Defense': 95.0,
#   'HP': 126.0,
#   'Name': 'Xerneas',
#   'SpecialAttack': 131.0,
#   'SpecialDefense': 98.0,
#   'Speed': 99.0,
#   'Total': 680.0,
#   'Type': 'Fairy'},
#  717.0: {'Attack': 131.0,
#   'Defense': 95.0,
#   'HP': 126.0,
#   'Name': 'Yveltal',
#   'SpecialAttack': 131.0,
#   'SpecialDefense': 98.0,
#   'Speed': 99.0,
#   'Total': 680.0,
#   'Type': 'DarkFlying'},
#  718.0: {'Attack': 100.0,
#   'Defense': 121.0,
#   'HP': 108.0,
#   'Name': 'Zygarde50% Forme',
#   'SpecialAttack': 81.0,
#   'SpecialDefense': 95.0,
#   'Speed': 95.0,
#   'Total': 600.0,
#   'Type': 'DragonGround'},
#  719.0: {'Attack': 160.0,
#   'Defense': 110.0,
#   'HP': 50.0,
#   'Name': 'DiancieMega Diancie',
#   'SpecialAttack': 160.0,
#   'SpecialDefense': 110.0,
#   'Speed': 110.0,
#   'Total': 700.0,
#   'Type': 'RockFairy'},
#  720.0: {'Attack': 160.0,
#   'Defense': 60.0,
#   'HP': 80.0,
#   'Name': 'HoopaHoopa Unbound',
#   'SpecialAttack': 170.0,
#   'SpecialDefense': 130.0,
#   'Speed': 80.0,
#   'Total': 680.0,
#   'Type': 'PsychicDark'},
#  721.0: {'Attack': 110.0,
#   'Defense': 120.0,
#   'HP': 80.0,
#   'Name': 'Volcanion',
#   'SpecialAttack': 130.0,
#   'SpecialDefense': 90.0,
#   'Speed': 70.0,
#   'Total': 600.0,
#   'Type': 'FireWater'}}

# %% [markdown]
# <img src="http://imgur.com/GCAf1UX.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 10. Write a function to generate a "filtered" pokedex
# ---
# Your function should:
# 1. Take the parsed pokedex information you created above as an argument.
# 1. Take a dictionary as a parameter with keys matching the features of the Pokedex, filtering by exact match for string type values, and/or filter continuous variables specified value that is greater than or equal to the dictionary key parameter.
# 1. Return multiple elements from the Pokedex
#
# Example:
#
# ```python
#
# # Only filter based on parameters passed
# filter_options = {
#     'Attack':   25,
#     'Defense':  30,
#     'Type':     'Electric'
# }
#
# # Return records with attack >= 24, defense >= 30, and type == "Electric"
# # Also anticipate that other paramters can also be passed such as "SpecialAttack", "Speed", etc.
# filtered_pokedex(pokedex_data, filter=filter_options)
#
# # Example output:
# # [{'Attack': 30.0,
# #  'Defense': 50.0,
# #  'HP': 40.0,
# #  'Name': 'Voltorb',
# #  'SpecialAttack': 55.0,
# #  'SpecialDefense': 55.0,
# #  'Speed': 100.0,
# #  'Total': 330.0,
# #  'Type': 'Electric'},
# #  {'Attack': 30.0,
# #  'Defense': 33.0,
# #  'HP': 32.0,
# #  'Name': 'Pikachu',
# #  'SpecialAttack': 55.0,
# #  'SpecialDefense': 55.0,
# #  'Speed': 100.0,
# #  'Total': 330.0,
# #  'Type': 'Electric'},
# #  ... etc
# #  ]
#
# ```

# %%
# stuck on this, wasn't able to complete in time! 

filter_options = {
    'Attack':   25,
    'Defense':  30,
    'Type':     'Electric'
}

holder_list = []

for value in outer_dict.values():
    holder_dict = {}
    for key in filter_options.keys():
        holder_dict[key] = value[key]
        
holder_dict
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-170-f86ab3be4db6> in <module>()
#      12     holder_dict = {}
#      13     for key in filter_options.keys():
# ---> 14         holder_dict[key] = value[key]
#      15
#      16 holder_dict
#
# KeyError: 'Attack'
